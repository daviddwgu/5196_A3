# %% [markdown]
# # FIT5196 Assessment 3
# #### Student Name: Dawei Gu
# #### Student ID: 29910226
# Tutorial Section: FIT5196 Tutorial 12
#
# Tutor: Islam Nassar
#
# Start Date: 22/05/2019
#
# Last Modified Date: 01/06/2019
#
# Environment: Python 3.7 and Anaconda 2018.12 (64-bit)
#
# Libraries used: pandas,datetime, geopy, math, sklearn, matplotlib, geopandas, shapely

# %%
import pandas as pd
import datetime as dt
from geopy.distance import geodesic
import math
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import geopandas
import shapely.geometry as geometry

# %%
#read file into dataframe
house = pd.read_csv('29910226.csv')
house.head()
# Out:
#             ID             Address  Rooms Type      Price        Date  \
# 0  ID524428873     14 Woodmason St      3    h  1437000.0  16/04/2016
# 1  ID455142191       85 Radford Rd      5    h   791000.0  18/06/2016
# 2  ID385314378       34 Fewster Dr      3    h   970000.0  26/08/2017
# 3  ID205782381      41 Adelaide St      3    h   760000.0  23/09/2017
# 4  ID574190434  1/221 Westgarth St      3    t   865000.0  12/11/2016
#
#    Bathroom  Car  Landsize    Age  Lattitude  Longtitude
# 0       1.0  1.0     313.0  109.0  -37.85110   145.03170
# 1       3.0  1.0     961.0   34.0  -37.70240   144.98400
# 2       2.0  2.0     674.0   38.0  -37.88360   145.22805
# 3       1.0  1.0     697.0   69.0  -37.78036   144.81950
# 4       1.0  2.0     184.0   13.0  -37.78250   145.01040

# %%
# checking for duplicated data
house[house.duplicated()]
# Out:
#               ID                 Address  Rooms Type      Price        Date  \
# 58   ID227991548          33 Mountain St      2    h  1150000.0   7/05/2016
# 80   ID758306752        43 Ballantyne St      2    h   925000.0  24/09/2016
# 202  ID946117206          10/3 Allard St      1    u   275000.0  15/07/2017
# 218  ID386128852          114 Reynard St      3    h  1064000.0   8/10/2016
# 261  ID155519306              2 Hazel St      5    h  2125000.0  28/05/2016
# 282  ID636472299        23/530 Toorak Rd      2    u   511000.0  27/06/2016
# 345  ID650392186        2/41 Kangaroo Rd      3    u  1220500.0  24/06/2017
# 429  ID469847752        8/37 Victoria St      2    u   740000.0   8/04/2017
# 543  ID880656809            56 Pecham St      3    h   621000.0  22/04/2017
# 553  ID472390759         301/89 River St      2    u   930000.0   3/09/2016
# 563  ID236752982           76 Ogilvie St      3    h   960000.0   4/03/2017
# 571  ID470285370        1/36 Pleasant Rd      4    t  1738000.0  15/10/2016
# 577  ID707383464             25 Hardy St      4    h  1500000.0   3/12/2016
# 585  ID337914978         1/36 The Avenue      2    u   585000.0  15/07/2017
# 592  ID968176576           59 Sellars St      3    h   850000.0  22/07/2017
# 608  ID282152385            73 Pecham St      3    h   963500.0  27/05/2017
# 633  ID589073637             141 Gold St      2    h   845500.0   7/05/2016
# 650  ID384557170          7 Fairbairn Rd      3    h   520000.0   3/06/2017
# 670  ID630270562              4 Tudor Rd      5    h  1540500.0   9/09/2017
# 671  ID389916108            44 Severn St      3    h  1930000.0  10/12/2016
# 674  ID521656880             239 Punt Rd      3    h  1570000.0  27/06/2016
# 698  ID637311098         3/302 Grange Rd      2    u   405000.0  28/08/2016
# 700  ID631497594               4 Ella Ct      4    h  1300000.0   8/04/2017
# 701  ID713631606              71 Hume Av      4    h   410000.0   9/09/2017
# 702  ID198657690         25 Faversham Rd      4    h  2510000.0  13/05/2017
# 703  ID877736099          13 Rosemary Dr      3    h   572000.0  27/05/2017
# 704  ID337914978         1/36 The Avenue      2    u   585000.0  15/07/2017
# 705  ID828387705         13 McDougall St      2    h   619000.0  13/08/2016
# 706  ID286614327           11 Rebecca Cl      5    h   835500.0  29/07/2017
# 707  ID187135066         39 Wilkinson St      2    h   800000.0   3/09/2017
# 708  ID582089114             3 Speers Ct      4    h  1600000.0  19/08/2017
# 709  ID634535284        35 Finningley Dr      3    h   695000.0  27/05/2017
# 710  ID158999276             124 Cole St      4    h  1761000.0   6/08/2016
# 711  ID474719080            14 Arthur St      2    h  1065000.0  15/10/2016
# 712  ID550141293        1A Aberfeldie St      3    h  1195000.0   9/09/2017
# 713  ID494300549           37 Roberts St      3    h   891000.0  18/06/2016
# 714  ID754507287        416 Serpells Tce      4    h  1200000.0  19/08/2017
# 715  ID428230767       1/6 Corhampton Rd      3    u  1600000.0  29/07/2017
# 716  ID512732811  11/1051 Pascoe Vale Rd      2    u   280000.0  16/04/2016
# 717  ID309630222             7 Eaglet Ct      4    h   720000.0   3/06/2017
# 718  ID354076401              8 Norma Ct      3    h   850000.0   3/09/2016
# 719  ID959679005         15 Kingshott Cl      4    h  1500000.0  29/04/2017
#
#      Bathroom  Car  Landsize    Age  Lattitude  Longtitude
# 58        1.0  0.0     113.0  163.0  -37.83730   144.94930
# 80        1.0  1.0     258.0   49.0  -37.75840   144.99710
# 202       1.0  1.0    1388.0   49.0  -37.76840   144.94214
# 218       2.0  1.0     417.0   79.0  -37.74780   144.95830
# 261       3.0  2.0     603.0   39.0  -37.84370   145.06900
# 282       1.0  2.0       0.0   49.0  -37.84240   145.01840
# 345       2.0  2.0     462.0   54.0  -37.89767   145.07332
# 429       1.0  1.0       0.0   59.0  -37.88810   145.00970
# 543       1.0  1.0     694.0   49.0  -37.69770   144.91160
# 553       2.0  2.0       0.0   19.0  -37.83610   144.99660
# 563       1.0  2.0     549.0   69.0  -37.74790   144.89310
# 571       3.0  2.0     324.0   17.0  -37.83480   145.05030
# 577       3.0  1.0     365.0  129.0  -37.76240   144.96710
# 585       1.0  1.0     598.0   44.0  -37.87149   144.99746
# 592       1.0  2.0     766.0   45.0  -37.69821   145.08995
# 608       2.0  6.0     697.0   59.0  -37.69647   144.91130
# 633       1.0  1.0     179.0  129.0  -37.77420   144.95420
# 650       2.0  2.0     535.0   39.0  -37.79414   144.81855
# 670       2.0  2.0     726.0   49.0  -37.78133   145.10833
# 671       1.0  4.0     902.0   99.0  -37.81530   144.87960
# 674       1.0  2.0     248.0   59.0  -37.81980   144.98990
# 698       1.0  1.0       0.0   49.0  -37.90310   145.04440
# 700       2.0  2.0     872.0   49.0  -37.79060   145.11380
# 701       1.0  2.0     578.0   39.0  -37.71077   144.57198
# 702       3.0  2.0     789.0   99.0  -37.82140   145.08430
# 703       1.0  2.0     640.0   44.0  -37.65910   145.00549
# 704       1.0  1.0     598.0   44.0  -37.87149   144.99746
# 705       1.0  2.0     640.0   49.0  -37.70380   144.96380
# 706       5.0  4.0     570.0   29.0  -38.03335   145.13212
# 707       1.0  0.0     140.0  129.0  -37.76806   144.95980
# 708       2.0  2.0    4168.0   19.0  -37.74611   145.17835
# 709       1.0  2.0     676.0   39.0  -37.69636   144.88265
# 710       2.0  3.0     615.0   99.0  -37.89560   145.00260
# 711       1.0  3.0     507.0  109.0  -37.74370   144.99950
# 712       2.0  2.0     381.0  113.0  -37.75629   144.90626
# 713       3.0  1.0     292.0   21.0  -37.75050   144.86570
# 714       2.0  2.0     375.0   21.0  -37.77559   145.17933
# 715       2.0  2.0     314.0    7.0  -37.79386   145.06746
# 716       1.0  1.0     197.0   69.0  -37.68590   144.91640
# 717       2.0  3.0     649.0   34.0  -37.67681   145.06414
# 718       1.0  1.0     593.0   49.0  -37.76770   144.86740
# 719       3.0  2.0     450.0   13.0  -37.86170   144.87860

# %%
# Since there is duplicated data, drop the duplicated data
house = house.drop_duplicates()
len(house)
# Out:
# 678

# %%
# Since some rows have been dropped, so reset index
house= house.reset_index()
del house['index']
house.head()
# Out:
#             ID             Address  Rooms Type      Price        Date  \
# 0  ID524428873     14 Woodmason St      3    h  1437000.0  16/04/2016
# 1  ID455142191       85 Radford Rd      5    h   791000.0  18/06/2016
# 2  ID385314378       34 Fewster Dr      3    h   970000.0  26/08/2017
# 3  ID205782381      41 Adelaide St      3    h   760000.0  23/09/2017
# 4  ID574190434  1/221 Westgarth St      3    t   865000.0  12/11/2016
#
#    Bathroom  Car  Landsize    Age  Lattitude  Longtitude
# 0       1.0  1.0     313.0  109.0  -37.85110   145.03170
# 1       3.0  1.0     961.0   34.0  -37.70240   144.98400
# 2       2.0  2.0     674.0   38.0  -37.88360   145.22805
# 3       1.0  1.0     697.0   69.0  -37.78036   144.81950
# 4       1.0  2.0     184.0   13.0  -37.78250   145.01040

# %%
#Extract the year data of house sold for future use
year_data = []
for index in range(len(house)):
    year_data.append(pd.to_datetime(house.loc[index,'Date']).year)
house['year'] = year_data

# %% [markdown]
# ## Task 1: Data Integration

# %% [markdown]
# ### 1.1 Suburb

# %%
#reading suburb shapefile as dataframe 
suburb = geopandas.read_file("vic_suburb_boundary\VIC_LOCALITY_POLYGON_shp.shp")
suburb.head()
# Out:
#   LC_PLY_PID   DT_CREATE DT_RETIRE  LOC_PID  VIC_LOCALI VIC_LOCA_1 VIC_LOCA_2  \
# 0       6670  2011-08-31      None  VIC2615  2012-04-27       None  UNDERBOOL
# 1       6671  2011-08-31      None  VIC1986  2012-04-27       None     NURRAN
# 2       6672  2011-08-31      None  VIC2862  2012-04-27       None   WOORNDOO
# 3       6673  2011-08-31      None   VIC734  2017-08-09       None   DEPTFORD
# 4       6674  2011-08-31      None  VIC2900  2012-04-27       None      YANAC
#
#   VIC_LOCA_3 VIC_LOCA_4 VIC_LOCA_5 VIC_LOCA_6 VIC_LOCA_7  \
# 0       None       None          G       None          2
# 1       None       None          G       None          2
# 2       None       None          G       None          2
# 3       None       None          G       None          2
# 4       None       None          G       None          2
#
#                                             geometry
# 0  POLYGON ((141.74552399 -35.07228701, 141.74552...
# 1  POLYGON ((148.668767 -37.39571245, 148.6687620...
# 2  POLYGON ((142.92287999 -37.97885997, 142.90449...
# 3  POLYGON ((147.82335712 -37.66000897, 147.82312...
# 4  POLYGON ((141.279783 -35.99858911, 141.2798853...

# %%
#rename the VIC_LOCA_2 column to suburb for easy interprete in furture, and the geometry column is the ploygon data of suburb
suburb.rename(columns={'VIC_LOCA_2':'suburb'}, inplace = True)
suburb.head()
# Out:
#   LC_PLY_PID   DT_CREATE DT_RETIRE  LOC_PID  VIC_LOCALI VIC_LOCA_1     suburb  \
# 0       6670  2011-08-31      None  VIC2615  2012-04-27       None  UNDERBOOL
# 1       6671  2011-08-31      None  VIC1986  2012-04-27       None     NURRAN
# 2       6672  2011-08-31      None  VIC2862  2012-04-27       None   WOORNDOO
# 3       6673  2011-08-31      None   VIC734  2017-08-09       None   DEPTFORD
# 4       6674  2011-08-31      None  VIC2900  2012-04-27       None      YANAC
#
#   VIC_LOCA_3 VIC_LOCA_4 VIC_LOCA_5 VIC_LOCA_6 VIC_LOCA_7  \
# 0       None       None          G       None          2
# 1       None       None          G       None          2
# 2       None       None          G       None          2
# 3       None       None          G       None          2
# 4       None       None          G       None          2
#
#                                             geometry
# 0  POLYGON ((141.74552399 -35.07228701, 141.74552...
# 1  POLYGON ((148.668767 -37.39571245, 148.6687620...
# 2  POLYGON ((142.92287999 -37.97885997, 142.90449...
# 3  POLYGON ((147.82335712 -37.66000897, 147.82312...
# 4  POLYGON ((141.279783 -35.99858911, 141.2798853...

# %%
#Matching the latitude and longitude of house to the geometry column of suburb dataset 
house['Suburb']='not available'
for i in range(len(house)):
    location = house.loc[i,'Longtitude'],house.loc[i,'Lattitude']
    print(i)
    for j in range(len(suburb)):
        if geometry.Point(location).within(geometry.shape(suburb.loc[j,'geometry'])):
            house.loc[i,'Suburb'] = suburb.loc[j,'suburb']
            print(suburb.loc[j,'suburb'])
            break
# Out:
# 0
# MALVERN
# 1
# RESERVOIR
# 2
# WANTIRNA SOUTH
# 3
# ALBION
# 4
# NORTHCOTE
# 5
# GLENROY
# 6
# BRUNSWICK WEST
# 7
# MITCHAM
# 8
# KEW EAST
# 9
# MILL PARK
# 10
# THORNBURY
# 11
# MOUNT WAVERLEY
# 12
# MITCHAM
# 13
# MARIBYRNONG
# 14
# CAMBERWELL
# 15
# FITZROY
# 16
# SOUTH MELBOURNE
# 17
# TOORAK
# 18
# ESSENDON WEST
# 19
# COLLINGWOOD
# 20
# FOOTSCRAY
# 21
# IVANHOE
# 22
# ABBOTSFORD
# 23
# BRUNSWICK WEST
# 24
# WEST MELBOURNE
# 25
# BUNDOORA
# 26
# VERMONT SOUTH
# 27
# ELWOOD
# 28
# SOUTH YARRA
# 29
# HAMPTON
# 30
# BENTLEIGH EAST
# 31
# COBURG
# 32
# OAKLEIGH
# 33
# BALWYN NORTH
# 34
# CRAIGIEBURN
# 35
# BRIGHTON
# 36
# HAMPTON
# 37
# HAMPTON
# 38
# ABERFELDIE
# 39
# HAWTHORN EAST
# 40
# THOMASTOWN
# 41
# ESSENDON
# 42
# ESSENDON NORTH
# 43
# MAIDSTONE
# 44
# RICHMOND
# 45
# IVANHOE
# 46
# RESERVOIR
# 47
# KEILOR EAST
# 48
# ESSENDON WEST
# 49
# WILLIAMSTOWN
# 50
# ASCOT VALE
# 51
# BRUNSWICK WEST
# 52
# ESSENDON
# 53
# PRAHRAN
# 54
# AVONDALE HEIGHTS
# 55
# NORTHCOTE
# 56
# BUNDOORA
# 57
# VIEWBANK
# 58
# COBURG
# 59
# DINGLEY VILLAGE
# 60
# RESERVOIR
# 61
# FITZROY NORTH
# 62
# NORTHCOTE
# 63
# ALTONA
# 64
# BRUNSWICK WEST
# 65
# MAIDSTONE
# 66
# ALTONA
# 67
# PRAHRAN
# 68
# KEILOR DOWNS
# 69
# CAULFIELD SOUTH
# 70
# BENTLEIGH
# 71
# WEST FOOTSCRAY
# 72
# SEDDON
# 73
# MULGRAVE
# 74
# THORNBURY
# 75
# COBURG
# 76
# MITCHAM
# 77
# TEMPLESTOWE LOWER
# 78
# HAWTHORN EAST
# 79
# CAMBERWELL
# 80
# WEST FOOTSCRAY
# 81
# SUNSHINE WEST
# 82
# ABBOTSFORD
# 83
# CARNEGIE
# 84
# VIEWBANK
# 85
# CARNEGIE
# 86
# NORTH MELBOURNE
# 87
# HAWTHORN
# 88
# ABERFELDIE
# 89
# RINGWOOD
# 90
# OAKLEIGH EAST
# 91
# FITZROY
# 92
# ARMADALE
# 93
# CHELSEA HEIGHTS
# 94
# COBURG
# 95
# OAK PARK
# 96
# HIGHETT
# 97
# NEWPORT
# 98
# BRUNSWICK EAST
# 99
# WINDSOR
# 100
# GLEN IRIS
# 101
# FITZROY
# 102
# PORT MELBOURNE
# 103
# HAMPTON
# 104
# TOORAK
# 105
# SOUTHBANK
# 106
# SOUTH YARRA
# 107
# NORTHCOTE
# 108
# BURWOOD
# 109
# BENTLEIGH
# 110
# NIDDRIE
# 111
# MARIBYRNONG
# 112
# BALACLAVA
# 113
# BOX HILL
# 114
# ESSENDON
# 115
# ELTHAM NORTH
# 116
# ALBANVALE
# 117
# KINGSBURY
# 118
# KEILOR EAST
# 119
# PRESTON
# 120
# ST KILDA
# 121
# ALPHINGTON
# 122
# GREENSBOROUGH
# 123
# CAULFIELD SOUTH
# 124
# RESERVOIR
# 125
# BRIGHTON
# 126
# STRATHMORE
# 127
# NIDDRIE
# 128
# CAMBERWELL
# 129
# KINGSVILLE
# 130
# CARLTON
# 131
# WILLIAMSTOWN
# 132
# BOX HILL
# 133
# GREENSBOROUGH
# 134
# RICHMOND
# 135
# KEILOR EAST
# 136
# MIDDLE PARK
# 137
# PASCOE VALE
# 138
# ESSENDON
# 139
# SEDDON
# 140
# ARMADALE
# 141
# COBURG
# 142
# MAIDSTONE
# 143
# COLLINGWOOD
# 144
# HEIDELBERG HEIGHTS
# 145
# BRIGHTON
# 146
# VIEWBANK
# 147
# BRUNSWICK
# 148
# GLENROY
# 149
# KEW
# 150
# SURREY HILLS
# 151
# OAK PARK
# 152
# ORMOND
# 153
# BRUNSWICK
# 154
# BRIGHTON
# 155
# RICHMOND
# 156
# WILLIAMSTOWN
# 157
# FITZROY
# 158
# FRANKSTON SOUTH
# 159
# HAWTHORN
# 160
# HEIDELBERG
# 161
# HAMPTON
# 162
# TEMPLESTOWE
# 163
# YARRAVILLE
# 164
# PASCOE VALE
# 165
# LALOR
# 166
# FOOTSCRAY
# 167
# PARKDALE
# 168
# KEILOR EAST
# 169
# SURREY HILLS
# 170
# SEAHOLME
# 171
# GOWANBRAE
# 172
# KEILOR PARK
# 173
# BENTLEIGH EAST
# 174
# MAIDSTONE
# 175
# SOUTH YARRA
# 176
# HAWTHORN EAST
# 177
# IVANHOE
# 178
# BRIGHTON EAST
# 179
# THORNBURY
# 180
# FITZROY
# 181
# NORTH MELBOURNE
# 182
# BRIGHTON EAST
# 183
# WATSONIA
# 184
# AVONDALE HEIGHTS
# 185
# TAYLORS LAKES
# 186
# BRUNSWICK WEST
# 187
# BRAYBROOK
# 188
# BRUNSWICK
# 189
# ALTONA
# 190
# KEILOR EAST
# 191
# BALWYN
# 192
# PRINCES HILL
# 193
# RICHMOND
# 194
# MURRUMBEENA
# 195
# FRANKSTON SOUTH
# 196
# ELSTERNWICK
# 197
# THOMASTOWN
# 198
# BENTLEIGH EAST
# 199
# BRUNSWICK WEST
# 200
# KEW EAST
# 201
# KEW
# 202
# ALTONA NORTH
# 203
# ESSENDON
# 204
# BURWOOD
# 205
# BRUNSWICK EAST
# 206
# BALWYN NORTH
# 207
# WEST FOOTSCRAY
# 208
# SURREY HILLS
# 209
# DANDENONG
# 210
# BALWYN NORTH
# 211
# PRESTON
# 212
# MOORABBIN
# 213
# ESSENDON NORTH
# 214
# SOUTH YARRA
# 215
# NEWPORT
# 216
# BRIGHTON
# 217
# CLIFTON HILL
# 218
# RICHMOND
# 219
# WATSONIA
# 220
# BALACLAVA
# 221
# RESERVOIR
# 222
# TOORAK
# 223
# BURWOOD
# 224
# BENTLEIGH EAST
# 225
# YARRAVILLE
# 226
# ESSENDON
# 227
# MOUNT WAVERLEY
# 228
# HADFIELD
# 229
# IVANHOE EAST
# 230
# CANTERBURY
# 231
# COBURG
# 232
# ELWOOD
# 233
# AIRPORT WEST
# 234
# PASCOE VALE
# 235
# SURREY HILLS
# 236
# DANDENONG NORTH
# 237
# OAKLEIGH
# 238
# ELTHAM
# 239
# ORMOND
# 240
# MOUNT WAVERLEY
# 241
# MIDDLE PARK
# 242
# RICHMOND
# 243
# SANDRINGHAM
# 244
# FAWKNER
# 245
# FAWKNER
# 246
# ST KILDA
# 247
# BENTLEIGH
# 248
# SUNSHINE WEST
# 249
# YARRAVILLE
# 250
# BALWYN
# 251
# KEW
# 252
# FRANKSTON SOUTH
# 253
# BRIGHTON
# 254
# COBURG
# 255
# PRESTON
# 256
# BRUNSWICK
# 257
# KEILOR EAST
# 258
# HAWTHORN
# 259
# HAWTHORN
# 260
# BELLFIELD
# 261
# BURWOOD
# 262
# KEW EAST
# 263
# GLENROY
# 264
# CARNEGIE
# 265
# RINGWOOD NORTH
# 266
# SPOTSWOOD
# 267
# MURRUMBEENA
# 268
# DONCASTER
# 269
# BRAYBROOK
# 270
# WESTMEADOWS
# 271
# DONCASTER
# 272
# BALWYN NORTH
# 273
# PORT MELBOURNE
# 274
# CAULFIELD
# 275
# FAWKNER
# 276
# IVANHOE EAST
# 277
# ORMOND
# 278
# ASCOT VALE
# 279
# SOUTH YARRA
# 280
# ELWOOD
# 281
# MONT ALBERT
# 282
# IVANHOE
# 283
# SURREY HILLS
# 284
# NEWPORT
# 285
# ALBERT PARK
# 286
# BURWOOD
# 287
# BRAYBROOK
# 288
# BAYSWATER NORTH
# 289
# BRIGHTON EAST
# 290
# HAMPTON
# 291
# ESSENDON
# 292
# KEW
# 293
# HAWTHORN
# 294
# WERRIBEE
# 295
# SURREY HILLS
# 296
# GLEN IRIS
# 297
# FITZROY NORTH
# 298
# PORT MELBOURNE
# 299
# ABERFELDIE
# 300
# RESERVOIR
# 301
# MOORABBIN
# 302
# MOONEE PONDS
# 303
# ALBERT PARK
# 304
# ELWOOD
# 305
# FAWKNER
# 306
# YARRAVILLE
# 307
# FOOTSCRAY
# 308
# WEST FOOTSCRAY
# 309
# BURWOOD EAST
# 310
# PORT MELBOURNE
# 311
# SOUTH YARRA
# 312
# BENTLEIGH
# 313
# MAIDSTONE
# 314
# ELWOOD
# 315
# FAIRFIELD
# 316
# WARRANDYTE
# 317
# WEST MELBOURNE
# 318
# TOORAK
# 319
# CAMBERWELL
# 320
# SOUTH YARRA
# 321
# RICHMOND
# 322
# GLENROY
# 323
# ASCOT VALE
# 324
# BRIGHTON
# 325
# MALVERN EAST
# 326
# MOORABBIN
# 327
# BRIGHTON EAST
# 328
# KINGSVILLE
# 329
# BENTLEIGH EAST
# 330
# ARMADALE
# 331
# WATSONIA NORTH
# 332
# RESERVOIR
# 333
# ASCOT VALE
# 334
# BURWOOD
# 335
# BRIGHTON
# 336
# WEST FOOTSCRAY
# 337
# RESERVOIR
# 338
# MALVERN
# 339
# PARKVILLE
# 340
# ARMADALE
# 341
# ABBOTSFORD
# 342
# BENTLEIGH EAST
# 343
# VIEWBANK
# 344
# SOUTH KINGSVILLE
# 345
# SURREY HILLS
# 346
# HEIDELBERG
# 347
# ASCOT VALE
# 348
# BERWICK
# 349
# CROYDON
# 350
# HAWTHORN EAST
# 351
# MELTON SOUTH
# 352
# GLADSTONE PARK
# 353
# TEMPLESTOWE LOWER
# 354
# DONCASTER
# 355
# YARRAVILLE
# 356
# ORMOND
# 357
# WATSONIA
# 358
# EPPING
# 359
# BENTLEIGH EAST
# 360
# CLIFTON HILL
# 361
# ARMADALE
# 362
# BRUNSWICK EAST
# 363
# MORDIALLOC
# 364
# WINDSOR
# 365
# BRUNSWICK
# 366
# SOUTH MELBOURNE
# 367
# THORNBURY
# 368
# BRUNSWICK WEST
# 369
# HAWTHORN EAST
# 370
# ELSTERNWICK
# 371
# BRUNSWICK WEST
# 372
# DONCASTER
# 373
# HAMPTON
# 374
# COBURG NORTH
# 375
# SUNBURY
# 376
# PRAHRAN
# 377
# WANTIRNA SOUTH
# 378
# LOWER PLENTY
# 379
# CHELTENHAM
# 380
# SOUTHBANK
# 381
# HEIDELBERG WEST
# 382
# RESERVOIR
# 383
# PRESTON
# 384
# RESERVOIR
# 385
# SOUTH YARRA
# 386
# CARLTON
# 387
# BRUNSWICK
# 388
# BENTLEIGH EAST
# 389
# MENTONE
# 390
# SUNSHINE WEST
# 391
# ROXBURGH PARK
# 392
# MOONEE PONDS
# 393
# MALVERN
# 394
# GLEN IRIS
# 395
# SOUTHBANK
# 396
# FRANKSTON SOUTH
# 397
# KEYSBOROUGH
# 398
# BLACKBURN
# 399
# ALTONA
# 400
# ST KILDA
# 401
# MOORABBIN
# 402
# RICHMOND
# 403
# ABERFELDIE
# 404
# BRIGHTON EAST
# 405
# AIRPORT WEST
# 406
# SOUTH MELBOURNE
# 407
# YALLAMBIE
# 408
# TOORAK
# 409
# BRIAR HILL
# 410
# TEMPLESTOWE LOWER
# 411
# BROADMEADOWS
# 412
# KEW
# 413
# BALWYN
# 414
# MALVERN EAST
# 415
# BENTLEIGH EAST
# 416
# WILLIAMSTOWN
# 417
# BRUNSWICK
# 418
# COBURG
# 419
# BRUNSWICK
# 420
# BULLEEN
# 421
# CAULFIELD SOUTH
# 422
# CAULFIELD SOUTH
# 423
# NEWPORT
# 424
# CARRUM DOWNS
# 425
# SEDDON
# 426
# SOUTH YARRA
# 427
# MONT ALBERT
# 428
# BALWYN NORTH
# 429
# MELTON WEST
# 430
# ORMOND
# 431
# MELTON SOUTH
# 432
# BRUNSWICK WEST
# 433
# MALVERN
# 434
# COBURG NORTH
# 435
# CRAIGIEBURN
# 436
# AVONDALE HEIGHTS
# 437
# GLEN WAVERLEY
# 438
# ABERFELDIE
# 439
# MOONEE PONDS
# 440
# SOUTHBANK
# 441
# BALWYN
# 442
# MALVERN EAST
# 443
# MALVERN EAST
# 444
# YALLAMBIE
# 445
# WHEELERS HILL
# 446
# KEYSBOROUGH
# 447
# GREENSBOROUGH
# 448
# TOORAK
# 449
# EDITHVALE
# 450
# PASCOE VALE
# 451
# WEST FOOTSCRAY
# 452
# BRUNSWICK WEST
# 453
# PRAHRAN
# 454
# NEWPORT
# 455
# YARRAVILLE
# 456
# BELLFIELD
# 457
# CLAYTON SOUTH
# 458
# CARNEGIE
# 459
# MALVERN EAST
# 460
# ELSTERNWICK
# 461
# MAIDSTONE
# 462
# HAWTHORN
# 463
# BULLEEN
# 464
# MELBOURNE
# 465
# BALWYN
# 466
# BENTLEIGH
# 467
# ELWOOD
# 468
# TULLAMARINE
# 469
# CAMBERWELL
# 470
# SUNSHINE
# 471
# BRIGHTON EAST
# 472
# COBURG
# 473
# IVANHOE
# 474
# COBURG
# 475
# WERRIBEE
# 476
# RESERVOIR
# 477
# FOOTSCRAY
# 478
# WEST FOOTSCRAY
# 479
# DONCASTER
# 480
# WEST MELBOURNE
# 481
# RICHMOND
# 482
# TOORAK
# 483
# CLAYTON SOUTH
# 484
# FITZROY
# 485
# CLIFTON HILL
# 486
# TOORAK
# 487
# STRATHMORE
# 488
# ELSTERNWICK
# 489
# BRIGHTON
# 490
# TARNEIT
# 491
# HIGHETT
# 492
# BRIGHTON
# 493
# MOORABBIN
# 494
# RICHMOND
# 495
# NEWPORT
# 496
# SOUTH YARRA
# 497
# WILLIAMSTOWN
# 498
# ALTONA NORTH
# 499
# SOUTH YARRA
# 500
# MIDDLE PARK
# 501
# BALACLAVA
# 502
# WOLLERT
# 503
# DINGLEY VILLAGE
# 504
# PRESTON
# 505
# MARIBYRNONG
# 506
# RESERVOIR
# 507
# VIEWBANK
# 508
# BENTLEIGH EAST
# 509
# GLENROY
# 510
# CREMORNE
# 511
# DONCASTER EAST
# 512
# KEW EAST
# 513
# BENTLEIGH
# 514
# MARIBYRNONG
# 515
# COBURG
# 516
# ALBERT PARK
# 517
# EMERALD
# 518
# DONCASTER
# 519
# ESSENDON
# 520
# DONCASTER EAST
# 521
# BRIGHTON EAST
# 522
# PRESTON
# 523
# MILL PARK
# 524
# KEW EAST
# 525
# MARIBYRNONG
# 526
# ESSENDON
# 527
# ESSENDON
# 528
# RICHMOND
# 529
# GLEN WAVERLEY
# 530
# TRAVANCORE
# 531
# SURREY HILLS
# 532
# KEILOR EAST
# 533
# RESERVOIR
# 534
# BRUNSWICK EAST
# 535
# WEST MELBOURNE
# 536
# SOUTH YARRA
# 537
# KENSINGTON
# 538
# CAULFIELD NORTH
# 539
# ESSENDON
# 540
# NIDDRIE
# 541
# DONCASTER
# 542
# CLAYTON
# 543
# DONVALE
# 544
# MITCHAM
# 545
# DONCASTER
# 546
# ALBION
# 547
# GLEN IRIS
# 548
# MALVERN EAST
# 549
# ESSENDON
# 550
# BRUNSWICK EAST
# 551
# FITZROY NORTH
# 552
# PASCOE VALE
# 553
# GLENROY
# 554
# NEWPORT
# 555
# ALBERT PARK
# 556
# FRANKSTON
# 557
# MELTON
# 558
# HEIDELBERG HEIGHTS
# 559
# BENTLEIGH EAST
# 560
# HILLSIDE
# 561
# KENSINGTON
# 562
# ALBERT PARK
# 563
# EPPING
# 564
# YARRAVILLE
# 565
# HILLSIDE
# 566
# PRAHRAN
# 567
# MITCHAM
# 568
# BRUNSWICK
# 569
# ASHWOOD
# 570
# ESSENDON
# 571
# RICHMOND
# 572
# SYDENHAM
# 573
# MELBOURNE
# 574
# ARMADALE
# 575
# RESERVOIR
# 576
# TOORAK
# 577
# SURREY HILLS
# 578
# NORTHCOTE
# 579
# FLEMINGTON
# 580
# YARRAVILLE
# 581
# FOOTSCRAY
# 582
# HADFIELD
# 583
# CHADSTONE
# 584
# MURRUMBEENA
# 585
# WILLIAMSTOWN
# 586
# ABERFELDIE
# 587
# BURNLEY
# 588
# GLENROY
# 589
# HAWTHORN
# 590
# HUGHESDALE
# 591
# PARKVILLE
# 592
# WEST FOOTSCRAY
# 593
# HAWTHORN EAST
# 594
# DOVETON
# 595
# ALBERT PARK
# 596
# DONCASTER EAST
# 597
# ALTONA NORTH
# 598
# ROSANNA
# 599
# BALWYN NORTH
# 600
# NORTHCOTE
# 601
# CRAIGIEBURN
# 602
# ARMADALE
# 603
# SUNSHINE NORTH
# 604
# KEILOR EAST
# 605
# SOUTH MORANG
# 606
# MENTONE
# 607
# RICHMOND
# 608
# DONCASTER EAST
# 609
# JACANA
# 610
# HILLSIDE
# 611
# KEW
# 612
# HEIDELBERG HEIGHTS
# 613
# THORNBURY
# 614
# SOUTH MELBOURNE
# 615
# ASHWOOD
# 616
# MOONEE PONDS
# 617
# JACANA
# 618
# ASHBURTON
# 619
# KEW
# 620
# PARKDALE
# 621
# BRIGHTON EAST
# 622
# SOUTH YARRA
# 623
# CARNEGIE
# 624
# BRIGHTON
# 625
# PORT MELBOURNE
# 626
# IVANHOE
# 627
# BALWYN
# 628
# JACANA
# 629
# NEWPORT
# 630
# ELWOOD
# 631
# KENSINGTON
# 632
# SUNBURY
# 633
# COLLINGWOOD
# 634
# BRUNSWICK
# 635
# WEST FOOTSCRAY
# 636
# PRESTON
# 637
# PARKDALE
# 638
# MOUNT WAVERLEY
# 639
# MOONEE PONDS
# 640
# NORTHCOTE
# 641
# ABBOTSFORD
# 642
# NORTHCOTE
# 643
# BRIGHTON
# 644
# BRUNSWICK
# 645
# HAWTHORN
# 646
# ABERFELDIE
# 647
# HEIDELBERG WEST
# 648
# CAULFIELD SOUTH
# 649
# GREENSBOROUGH
# 650
# PASCOE VALE
# 651
# YARRAVILLE
# 652
# AVONDALE HEIGHTS
# 653
# BRIGHTON EAST
# 654
# NORTHCOTE
# 655
# ESSENDON
# 656
# ALTONA
# 657
# MALVERN EAST
# 658
# COBURG
# 659
# MITCHAM
# 660
# MOONEE PONDS
# 661
# HEIDELBERG HEIGHTS
# 662
# PRESTON
# 663
# MIDDLE PARK
# 664
# CLIFTON HILL
# 665
# NORTH MELBOURNE
# 666
# IVANHOE
# 667
# SOUTH YARRA
# 668
# BENTLEIGH EAST
# 669
# MOORABBIN
# 670
# ESSENDON
# 671
# BURWOOD
# 672
# ASHWOOD
# 673
# BENTLEIGH EAST
# 674
# KEW
# 675
# MULGRAVE
# 676
# PRESTON
# 677
# ASHWOOD

# %%
# Check is there no matching in house dataframe
house[house['Suburb'] == 'not available']
# Out:
# Empty DataFrame
# Columns: [ID, Address, Rooms, Type, Price, Date, Bathroom, Car, Landsize, Age, Lattitude, Longtitude, year, Suburb]
# Index: []

# %% [markdown]
# ### 1.2 over_priced

# %%
#Define a function to compare the price of house with the median price of same situation of house, if the price is higher than median price, 
# return True. If the price is lower or equal to median price, return False. If other situation, return -1.
def compare_price(room, house_type, bathroom,car, sold_year,surb,price):
    try:
        median_price = house[(house['Rooms']==room)&(house['Type']==house_type)&(house['Bathroom']==bathroom)&
                             (house['Car']==car)&(house['year']==sold_year)&(house['Suburb']==surb)]['Price'].median()
        if price > median_price:
            result = 1
        elif price <= median_price:
            result = 0
    except Exception as ex:
        result = -1
    finally:
        return result

# %%
# Apply function to hosue data, and creat column called 'over_periced' to store result. 
over_priced=[]
for i in range(len(house)):
    over_priced.append(compare_price(house.loc[i,'Rooms'],house.loc[i,'Type'],house.loc[i,'Bathroom'],house.loc[i,'Car']
                                    ,house.loc[i,'year'],house.loc[i,'Suburb'],house.loc[i,'Price'] ))
house['over_priced?'] = over_priced

# %%
# Check the result
house['over_priced?'].value_counts()
# Out:
# 0    632
# 1     46
# Name: over_priced?, dtype: int64

# %% [markdown]
# ### 1.3 Crime_data

# %%
#Read the council file to get the area suburb data as a list
def reading_file(file_path):
    file_handle = open(file_path, "r")
    list_data = []
    for line in file_handle:
        #first part is area
        first_item = line.strip().split(":")[0]
        #second part is suburb list of that area
        temp_second_item = line.strip().split(":")[1].replace('[','').replace(']','').split(',')
        second_item = []
        for item in temp_second_item:
            #remove extra '' inside each suburb string, and make string to upper case
            second_item.append(eval(item).upper())
        list_data.append([first_item,second_item])  
    file_handle.close
    return list_data
council = reading_file('councils.txt')
council[0:10]
# Out:
# [['BANYULE ', ['ABBOTSFORD', 'AIRPORT WEST', 'ALBERT PARK', 'ALPHINGTON']],
#  ['BRIMBANK ', ['ALTONA', 'ALTONA NORTH', 'ARMADALE', 'ASCOT VALE']],
#  ['DAREBIN ', ['ASHBURTON', 'ASHWOOD', 'AVONDALE HEIGHTS', 'BALACLAVA']],
#  ['HOBSONS BAY ', ['BALWYN', 'BALWYN NORTH', 'BENTLEIGH', 'BENTLEIGH EAST']],
#  ['HUME ', ['BOX HILL', 'BRAYBROOK', 'BRIGHTON', 'BRIGHTON EAST']],
#  ['MARIBYRNONG ', ['BRUNSWICK', 'BRUNSWICK WEST', 'BULLEEN', 'BURWOOD']],
#  ['MELBOURNE ', ['CAMBERWELL', 'CANTERBURY', 'CARLTON NORTH', 'CARNEGIE']],
#  ['MELTON ', ['CAULFIELD', 'CAULFIELD NORTH', 'CAULFIELD SOUTH', 'CHADSTONE']],
#  ['MOONEE VALLEY ', ['CLIFTON HILL', 'COBURG', 'COBURG NORTH', 'COLLINGWOOD']],
#  ['MORELAND ', ['DONCASTER', 'EAGLEMONT', 'ELSTERNWICK', 'ELWOOD']]]

# %%
#determine the area of each house located
def found_area(suburb):
    result = 'unknown'
    try:
        for i in range(len(council)):
            # check each area, check the suburb is in area's suburb list or not, match return area name
            if suburb in council[i][1]:
                result = council[i][0]
    except Exception as ex:
        result = 'unknown'
    finally:
        return result
house['area'] = house['Suburb'].apply(found_area)
house.head(5)
# Out:
#             ID             Address  Rooms Type      Price        Date  \
# 0  ID524428873     14 Woodmason St      3    h  1437000.0  16/04/2016
# 1  ID455142191       85 Radford Rd      5    h   791000.0  18/06/2016
# 2  ID385314378       34 Fewster Dr      3    h   970000.0  26/08/2017
# 3  ID205782381      41 Adelaide St      3    h   760000.0  23/09/2017
# 4  ID574190434  1/221 Westgarth St      3    t   865000.0  12/11/2016
#
#    Bathroom  Car  Landsize    Age  Lattitude  Longtitude  year  \
# 0       1.0  1.0     313.0  109.0  -37.85110   145.03170  2016
# 1       3.0  1.0     961.0   34.0  -37.70240   144.98400  2016
# 2       2.0  2.0     674.0   38.0  -37.88360   145.22805  2017
# 3       1.0  1.0     697.0   69.0  -37.78036   144.81950  2017
# 4       1.0  2.0     184.0   13.0  -37.78250   145.01040  2016
#
#            Suburb  over_priced?             area
# 0         MALVERN             0         BAW BAW
# 1       RESERVOIR             0  EAST GIPPSLAND
# 2  WANTIRNA SOUTH             0          LODDON
# 3          ALBION             1           MOIRA
# 4       NORTHCOTE             0     MURRINDINDI

# %%
# Check the area result
len(house[(house['area']=='unknown')])
# Out:
# 0

# %%
#Read the crime file
xls = pd.ExcelFile('crimebylocationdatatable-yearending31march2016.xlsx')
crime = pd.read_excel(xls, 'Table 1')
crime
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# 5            NaN                                                NaN
# 6            NaN                                                NaN
# 7            NaN                                                NaN
# 8            NaN                                                NaN
# 9            NaN  Table 1. Number of offences by geographic area...
# 10           NaN                                                NaN
# 11           NaN                                                NaN
# 12           NaN                                                NaN
# 13           NaN                                                NaN
# 14           NaN                                                NaN
# 15           NaN                                                NaN
# 16           NaN                                                NaN
# 17           NaN                                                NaN
# 18           NaN                         Apr - Mar reference period
# 19           NaN                                               2012
# 20           NaN                                               2012
# 21           NaN                                               2012
# 22           NaN                                               2012
# 23           NaN                                               2012
# 24           NaN                                               2012
# 25           NaN                                               2012
# 26           NaN                                               2012
# 27           NaN                                               2012
# 28           NaN                                               2012
# 29           NaN                                               2012
# ...          ...                                                ...
# 9074         NaN                                               2016
# 9075         NaN                                               2016
# 9076         NaN                                               2016
# 9077         NaN                                               2016
# 9078         NaN                                               2016
# 9079         NaN                                               2016
# 9080         NaN                                               2016
# 9081         NaN                                               2016
# 9082         NaN                                               2016
# 9083         NaN                                               2016
# 9084         NaN                                               2016
# 9085         NaN                                               2016
# 9086         NaN                                               2016
# 9087         NaN                                               2016
# 9088         NaN                                               2016
# 9089         NaN                                               2016
# 9090         NaN                                               2016
# 9091         NaN                                               2016
# 9092         NaN                                               2016
# 9093         NaN                                               2016
# 9094         NaN                                               2016
# 9095         NaN                                               2016
# 9096         NaN                                               2016
# 9097         NaN                                               2016
# 9098         NaN                                               2016
# 9099         NaN                                               2016
# 9100         NaN                                               2016
# 9101         NaN                                               2016
# 9102         NaN                                               2016
# 9103         NaN                                               2016
#
#               Unnamed: 2           Unnamed: 3             Unnamed: 4  \
# 0                    NaN                  NaN                    NaN
# 1                    NaN                  NaN                    NaN
# 2                    NaN                  NaN                    NaN
# 3                    NaN                  NaN                    NaN
# 4                    NaN                  NaN                    NaN
# 5                    NaN                  NaN                    NaN
# 6                    NaN                  NaN                    NaN
# 7                    NaN                  NaN                    NaN
# 8                    NaN                  NaN                    NaN
# 9                    NaN                  NaN                    NaN
# 10                   NaN                  NaN                    NaN
# 11                   NaN                  NaN                    NaN
# 12                   NaN                  NaN                    NaN
# 13                   NaN                  NaN                    NaN
# 14                   NaN                  NaN                    NaN
# 15                   NaN                  NaN                    NaN
# 16                   NaN                  NaN                    NaN
# 17                   NaN                  NaN                    NaN
# 18         Police Region  Police Service Area  Local Government Area
# 19    1 North West Metro              BANYULE                BANYULE
# 20    1 North West Metro              BANYULE                BANYULE
# 21    1 North West Metro              BANYULE                BANYULE
# 22    1 North West Metro              BANYULE                BANYULE
# 23    1 North West Metro              BANYULE                BANYULE
# 24    1 North West Metro              BANYULE                BANYULE
# 25    1 North West Metro              BANYULE                BANYULE
# 26    1 North West Metro              BANYULE                BANYULE
# 27    1 North West Metro              BANYULE                BANYULE
# 28    1 North West Metro              BANYULE                BANYULE
# 29    1 North West Metro              BANYULE                BANYULE
# ...                  ...                  ...                    ...
# 9074           4 Western          WARRNAMBOOL                  MOYNE
# 9075           4 Western          WARRNAMBOOL                  MOYNE
# 9076           4 Western          WARRNAMBOOL                  MOYNE
# 9077           4 Western          WARRNAMBOOL                  MOYNE
# 9078           4 Western          WARRNAMBOOL                  MOYNE
# 9079           4 Western          WARRNAMBOOL                  MOYNE
# 9080           4 Western          WARRNAMBOOL                  MOYNE
# 9081           4 Western          WARRNAMBOOL                  MOYNE
# 9082           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9083           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9084           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9085           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9086           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9087           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9088           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9089           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9090           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9091           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9092           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9093           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9094           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9095           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9096           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9097           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9098           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9099           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9100           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9101           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9102           4 Western          WARRNAMBOOL            WARRNAMBOOL
# 9103           4 Western          WARRNAMBOOL            WARRNAMBOOL
#
#                                 Unnamed: 5  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                    CSA Offence Division
# 19             A Crimes against the person
# 20             A Crimes against the person
# 21             A Crimes against the person
# 22             A Crimes against the person
# 23             A Crimes against the person
# 24             A Crimes against the person
# 25             A Crimes against the person
# 26             A Crimes against the person
# 27       B Property and deception offences
# 28       B Property and deception offences
# 29       B Property and deception offences
# ...                                    ...
# 9074                       C Drug offences
# 9075  D Public order and security offences
# 9076  D Public order and security offences
# 9077  D Public order and security offences
# 9078         E Justice procedures offences
# 9079         E Justice procedures offences
# 9080                      F Other offences
# 9081                      F Other offences
# 9082           A Crimes against the person
# 9083           A Crimes against the person
# 9084           A Crimes against the person
# 9085           A Crimes against the person
# 9086           A Crimes against the person
# 9087           A Crimes against the person
# 9088     B Property and deception offences
# 9089     B Property and deception offences
# 9090     B Property and deception offences
# 9091     B Property and deception offences
# 9092     B Property and deception offences
# 9093                       C Drug offences
# 9094                       C Drug offences
# 9095                       C Drug offences
# 9096  D Public order and security offences
# 9097  D Public order and security offences
# 9098  D Public order and security offences
# 9099         E Justice procedures offences
# 9100         E Justice procedures offences
# 9101                      F Other offences
# 9102                      F Other offences
# 9103                      F Other offences
#
#                                              Unnamed: 6     Unnamed: 7  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# 5                                                   NaN            NaN
# 6                                                   NaN            NaN
# 7                                                   NaN            NaN
# 8                                                   NaN            NaN
# 9                                                   NaN            NaN
# 10                                                  NaN            NaN
# 11                                                  NaN            NaN
# 12                                                  NaN            NaN
# 13                                                  NaN            NaN
# 14                                                  NaN            NaN
# 15                                                  NaN            NaN
# 16                                                  NaN            NaN
# 17                                                  NaN            NaN
# 18                              CSA Offence Subdivision  Offence Count
# 19                    A10 Homicide and related offences              4
# 20                     A20 Assault and related offences            568
# 21                                  A30 Sexual offences            132
# 22                   A40 Abduction and related offences             12
# 23                                          A50 Robbery             46
# 24                          A60 Blackmail and extortion              2
# 25    A70 Stalking, harassment and threatening behav...            148
# 26    A80 Dangerous and negligent acts endangering p...             75
# 27                                            B10 Arson             53
# 28                                  B20 Property damage            938
# 29                         B30 Burglary/Break and enter            918
# ...                                                 ...            ...
# 9074                        C30 Drug use and possession             85
# 9075                D10 Weapons and explosives offences             48
# 9076               D20 Disorderly and offensive conduct             60
# 9077                       D30 Public nuisance offences              4
# 9078                             E10 Justice procedures             26
# 9079                             E20 Breaches of orders            238
# 9080           F30 Other government regulatory offences              2
# 9081                         F90 Miscellaneous offences              3
# 9082                   A20 Assault and related offences            219
# 9083                                A30 Sexual offences             73
# 9084                 A40 Abduction and related offences             12
# 9085                                        A50 Robbery              3
# 9086  A70 Stalking, harassment and threatening behav...             68
# 9087  A80 Dangerous and negligent acts endangering p...             34
# 9088                                          B10 Arson             12
# 9089                                B20 Property damage            290
# 9090                       B30 Burglary/Break and enter            259
# 9091                                          B40 Theft            532
# 9092                                      B50 Deception             82
# 9093                   C10 Drug dealing and trafficking             39
# 9094                 C20 Cultivate or manufacture drugs             10
# 9095                        C30 Drug use and possession            172
# 9096                D10 Weapons and explosives offences            120
# 9097               D20 Disorderly and offensive conduct             89
# 9098                       D30 Public nuisance offences             34
# 9099                             E10 Justice procedures             79
# 9100                             E20 Breaches of orders            360
# 9101                  F20 Transport regulation offences              2
# 9102           F30 Other government regulatory offences              4
# 9103                         F90 Miscellaneous offences              1
#
#      Unnamed: 8     Unnamed: 9
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
# 5           NaN            NaN
# 6           NaN            NaN
# 7           NaN            NaN
# 8           NaN            NaN
# 9           NaN            NaN
# 10          NaN            NaN
# 11          NaN            NaN
# 12          NaN            NaN
# 13          NaN            NaN
# 14          NaN            NaN
# 15          NaN            NaN
# 16          NaN            NaN
# 17          NaN            NaN
# 18      LGA ERP  Victorian ERP
# 19       123600        5632521
# 20       123600        5632521
# 21       123600        5632521
# 22       123600        5632521
# 23       123600        5632521
# 24       123600        5632521
# 25       123600        5632521
# 26       123600        5632521
# 27       123600        5632521
# 28       123600        5632521
# 29       123600        5632521
# ...         ...            ...
# 9074      16503        6053355
# 9075      16503        6053355
# 9076      16503        6053355
# 9077      16503        6053355
# 9078      16503        6053355
# 9079      16503        6053355
# 9080      16503        6053355
# 9081      16503        6053355
# 9082      33795        6053355
# 9083      33795        6053355
# 9084      33795        6053355
# 9085      33795        6053355
# 9086      33795        6053355
# 9087      33795        6053355
# 9088      33795        6053355
# 9089      33795        6053355
# 9090      33795        6053355
# 9091      33795        6053355
# 9092      33795        6053355
# 9093      33795        6053355
# 9094      33795        6053355
# 9095      33795        6053355
# 9096      33795        6053355
# 9097      33795        6053355
# 9098      33795        6053355
# 9099      33795        6053355
# 9100      33795        6053355
# 9101      33795        6053355
# 9102      33795        6053355
# 9103      33795        6053355
#
# [9104 rows x 10 columns]

# %%
# Since the first column is all null value, so drop the first column, drop all of the row with null value
del crime['Unnamed: 0']
crime.dropna(axis=0,inplace=True)
crime.head()
# Out:
#                     Unnamed: 1          Unnamed: 2           Unnamed: 3  \
# 18  Apr - Mar reference period       Police Region  Police Service Area
# 19                        2012  1 North West Metro              BANYULE
# 20                        2012  1 North West Metro              BANYULE
# 21                        2012  1 North West Metro              BANYULE
# 22                        2012  1 North West Metro              BANYULE
#
#                Unnamed: 4                   Unnamed: 5  \
# 18  Local Government Area         CSA Offence Division
# 19                BANYULE  A Crimes against the person
# 20                BANYULE  A Crimes against the person
# 21                BANYULE  A Crimes against the person
# 22                BANYULE  A Crimes against the person
#
#                             Unnamed: 6     Unnamed: 7 Unnamed: 8  \
# 18             CSA Offence Subdivision  Offence Count    LGA ERP
# 19   A10 Homicide and related offences              4     123600
# 20    A20 Assault and related offences            568     123600
# 21                 A30 Sexual offences            132     123600
# 22  A40 Abduction and related offences             12     123600
#
#        Unnamed: 9
# 18  Victorian ERP
# 19        5632521
# 20        5632521
# 21        5632521
# 22        5632521

# %%
#Rename the column we may need, and drop the first row contain column name
crime.rename(columns={'Unnamed: 1':'year', 'Unnamed: 3':'police_area', 'Unnamed: 4':'government_area', 
                      'Unnamed: 5':'type', 'Unnamed: 7':'count'}, inplace = True)
crime.drop([18], axis=0,inplace=True)

# %%
# reset the index, and drop the orignal index column
crime= crime.reset_index()
del crime['index']
crime.head()
# Out:
#    year          Unnamed: 2 police_area government_area  \
# 0  2012  1 North West Metro     BANYULE         BANYULE
# 1  2012  1 North West Metro     BANYULE         BANYULE
# 2  2012  1 North West Metro     BANYULE         BANYULE
# 3  2012  1 North West Metro     BANYULE         BANYULE
# 4  2012  1 North West Metro     BANYULE         BANYULE
#
#                           type                          Unnamed: 6 count  \
# 0  A Crimes against the person   A10 Homicide and related offences     4
# 1  A Crimes against the person    A20 Assault and related offences   568
# 2  A Crimes against the person                 A30 Sexual offences   132
# 3  A Crimes against the person  A40 Abduction and related offences    12
# 4  A Crimes against the person                         A50 Robbery    46
#
#   Unnamed: 8 Unnamed: 9
# 0     123600    5632521
# 1     123600    5632521
# 2     123600    5632521
# 3     123600    5632521
# 4     123600    5632521

# %%
# Extract the crime type of each record
crime_type = []
for i in range(len(crime)):
    crime_type.append(crime.iloc[i,4][0])
crime["crime_type"] = crime_type
crime.head()
# Out:
#    year          Unnamed: 2 police_area government_area  \
# 0  2012  1 North West Metro     BANYULE         BANYULE
# 1  2012  1 North West Metro     BANYULE         BANYULE
# 2  2012  1 North West Metro     BANYULE         BANYULE
# 3  2012  1 North West Metro     BANYULE         BANYULE
# 4  2012  1 North West Metro     BANYULE         BANYULE
#
#                           type                          Unnamed: 6 count  \
# 0  A Crimes against the person   A10 Homicide and related offences     4
# 1  A Crimes against the person    A20 Assault and related offences   568
# 2  A Crimes against the person                 A30 Sexual offences   132
# 3  A Crimes against the person  A40 Abduction and related offences    12
# 4  A Crimes against the person                         A50 Robbery    46
#
#   Unnamed: 8 Unnamed: 9 crime_type
# 0     123600    5632521          A
# 1     123600    5632521          A
# 2     123600    5632521          A
# 3     123600    5632521          A
# 4     123600    5632521          A

# %%
# Function use to found the average number of crime in last 3 year of that area,
def found_crime_count(area, year, crime_type):
    try:
        result = crime[(crime['year']==(year-1))&(crime['government_area']==area)&(crime['crime_type']==crime_type)]['count'].sum()
        result += crime[(crime['year']==(year-2))&(crime['government_area']==area)&(crime['crime_type']==crime_type)]['count'].sum()
        result += crime[(crime['year']==(year-3))&(crime['government_area']==area)&(crime['crime_type']==crime_type)]['count'].sum()
        result = result/3
        if result == 0:
            result = -1
    except Exception as ex:
        result = -1
    finally:
        return int(result)

# %%
# Found the average number of type A crime for each row
type_a_crime = []
for i in range(len(house)):
    type_a_crime.append(found_crime_count(house.loc[i,'area'].strip(),house.loc[i,'year'], 'A'))
house['crime_A_average'] = type_a_crime

# %%
# check the number of row did not found data
len(house[house['crime_A_average']==-1])
# Out:
# 0

# %%
house['crime_A_average'].describe()
# Out:
# count     678.000000
# mean     1104.637168
# std       835.925748
# min        50.000000
# 25%       555.000000
# 50%       938.000000
# 75%      1479.000000
# max      3767.000000
# Name: crime_A_average, dtype: float64

# %%
# Found the average number of type B crime for each row
type_b_crime = []
for i in range(len(house)):
    type_b_crime.append(found_crime_count(house.loc[i,'area'].strip(),house.loc[i,'year'], 'B'))
house['crime_B_average'] = type_b_crime

# %%
# check the number of row did not found data
len(house[house['crime_B_average']==-1])
# Out:
# 0

# %%
# Found the average number of type C crime for each row
type_c_crime = []
for i in range(len(house)):
    type_c_crime.append(found_crime_count(house.loc[i,'area'].strip(),house.loc[i,'year'], 'C'))
house['crime_C_average'] = type_c_crime

# %%
# check the number of row did not found data
len(house[house['crime_C_average']==-1])
# Out:
# 0

# %%
# delate the temperate columns
del house['year']
del house['area']

# %% [markdown]
# ### 1.4 station_id and distance

# %% [markdown]
# #### Merge all of the relvent stop file, and relvent stop_times file

# %% [markdown]
# First, merge the stop id and stop_times file base on some conditons:
# - stop_times file only contain the record for the route have southern cross station
# - stop_times file only contain the record for the trip id work in all week day
# - stop_time file only contain the record infront of southern cross station(including southern cross station) station to ensure the direction of trip to southern cross station.
# - stop file only contain the stop id from stop_time file and departure bewteen 7:00 - 9:30 am.

# %%
#determine the southern cross station is in the stop dataframe or not, is it exist, return the stop id of southern cross station
def found_southern(stop):
    for i in range(len(stop)):
        if ('Southern Cross Railway Station (Melbourne City)'in stop.loc[i,'stop_name']):
            return stop.loc[i,'stop_id']
    return False

# %%
# extract the southern cross staiton stop id and route number list which contain southern cross staiton 
SC_id = []
route_list = []
for i in [1,2,3,4,5,6,7,8,10,11]:
    stop_file = pd.read_csv("gtfs/"+str(i)+"/google_transit/stops.txt")
    if found_southern(stop_file)!= False:
        SC_id.append(found_southern(stop_file))
        route_list.append(i)
SC_id = list(set(SC_id))
print(SC_id)
print(route_list)
# Out:
# [20043, 22180]
# [1, 2, 10]

# %%
#Built the first route fiel into main stop and main time dataframes

# read the calender data to check which service id was only run in the weekday, extract the service_id list
calendar_file = pd.read_csv("gtfs/1/google_transit/calendar.txt")
service_id_list = list(calendar_file[(calendar_file['monday']==1)&(calendar_file['tuesday']==1)&(calendar_file['wednesday']==1)
                                     &(calendar_file['thursday']==1)&(calendar_file['friday']==1)&(calendar_file['saturday']==0)
                                     &(calendar_file['sunday']==0)]['service_id'].unique())

# read the trips file to extract which trip_id is for the service_id list
trips_file = pd.read_csv("gtfs/1/google_transit/trips.txt")
trip_id_list = list(trips_file[trips_file['service_id'].isin(service_id_list)]['trip_id'].unique())

#read stop_time file
raw_time_main = pd.read_csv("gtfs/1/google_transit/stop_times.txt")

#filter the dataframe with the trip_id list only work in the weekday first.
raw_time_main = raw_time_main[raw_time_main['trip_id'].isin(trip_id_list)]
#extract the trip_id have southern cross station included.
SC_trip_id_list = list(raw_time_main[raw_time_main['stop_id'].isin(SC_id)]['trip_id'].unique())

#filtering the dataframe which only contain the station before the southern cross and southern cross, insure all of stop_time and stop record
# is the record that towards southern cross station
time_main = raw_time_main[raw_time_main['trip_id']==SC_trip_id_list[0]]
#found the seuqence number of southern cross station in that trip
SC_trip_seuqence = list(time_main[time_main['stop_id'].isin(SC_id)]['stop_sequence'])[0]
#Only add the sequence number smaller than southern cross station, and also including southern cross
time_main = time_main[time_main['stop_sequence']<= SC_trip_seuqence]
#Remove the fisrt trip
SC_trip_id_list.pop(0)
# Do the same thing to the rest of trip
for i_trip in SC_trip_id_list:
    temp_time_main= raw_time_main[raw_time_main['trip_id']==i_trip]
    SC_trip_seuqence = list(temp_time_main[temp_time_main['stop_id'].isin(SC_id)]['stop_sequence'])[0]
    temp_time_main = temp_time_main[temp_time_main['stop_sequence']<= SC_trip_seuqence]
    # merge this trip record to main
    time_main = pd.concat([time_main, temp_time_main], ignore_index=True)
#extract the stop id which the trip run time between 7:00-9:30.
stop_id_list = time_main[(time_main['departure_time']> '06:59:59')&(time_main['departure_time']< '09:30:01')]['stop_id'].unique()


#Read the stop file
stop_main = pd.read_csv("gtfs/1/google_transit/stops.txt")
#filter stop file with the stop id extract from pervious step
stop_main = stop_main[stop_main['stop_id'].isin(stop_id_list)]


print('stop_main:',len(stop_main))
print('time_main:',len(time_main))
# Out:
# stop_main: 89
# time_main: 8572

# %%
#Since the first route have been add into main file, remove the first one, and prepare list for reamin
route_list.pop(0)
route_list
# Out:
# [2, 10]

# %%
#merge the remain route file
for i in route_list:
    trip_id_list = []
    stop_id_list = []
    trip_id_list = []
    service_id_list= []
    
    # read the calender data to check which service id was only run in the weekday, extract the service_id list
    calendar_file = pd.read_csv("gtfs/"+str(i)+"/google_transit/calendar.txt")
    service_id_list = list(calendar_file[(calendar_file['monday']==1)&(calendar_file['tuesday']==1)&(calendar_file['wednesday']==1)
                                         &(calendar_file['thursday']==1)&(calendar_file['friday']==1)&(calendar_file['saturday']==0)
                                         &(calendar_file['sunday']==0)]['service_id'].unique())
    
    # read the trips file to check which trip_id is for the service_id list
    trips_file = pd.read_csv("gtfs/"+str(i)+"/google_transit/trips.txt")
    trip_id_list = list(trips_file[trips_file['service_id'].isin(service_id_list)]['trip_id'].unique())
    
    #read stop_time file
    raw_time_file = pd.read_csv("gtfs/"+str(i)+"/google_transit/stop_times.txt")
    #filter the dataframe with the trip_id only work in the weekday first.
    raw_time_file = raw_time_file[raw_time_file['trip_id'].isin(trip_id_list)]

    #extract the trip have southern cross station included.
    SC_trip_id_list = list(raw_time_file[raw_time_file['stop_id'].isin(SC_id)]['trip_id'].unique())
    
    #filtering the dataframe which only contain the station before the southern cross and southern cross, insure all of stop_time and stop record
    # is the record that towards southern cross station
    if SC_trip_id_list != []:
        time_file = raw_time_file[raw_time_file['trip_id']==SC_trip_id_list[0]]
        #found the seuqence number of southern cross station in that trip
        SC_trip_seuqence = list(time_file[time_file['stop_id'].isin(SC_id)]['stop_sequence'])[0]
        #Only add the sequence number smaller than southern cross station, and also including southern cross
        time_file = time_file[time_file['stop_sequence']<= SC_trip_seuqence]
        #Remove the fisrt trip
        SC_trip_id_list.pop(0)
        # Do the same thing to the rest of trip
        for i_trip in SC_trip_id_list:
            temp_time_file= raw_time_file[raw_time_file['trip_id']==i_trip]
            SC_trip_seuqence = list(temp_time_file[temp_time_file['stop_id'].isin(SC_id)]['stop_sequence'])[0]
            temp_time_file = temp_time_file[temp_time_file['stop_sequence']<= SC_trip_seuqence]
            # merge this trip record to main
            time_file = pd.concat([time_file, temp_time_file], ignore_index=True)
        
        #extract the stop id which the trip run time between 7:00-9:30.
        stop_id_list = time_file[(time_file['departure_time']> '06:59:59')&(time_file['departure_time']< '09:30:01')]['stop_id'].unique()
        #Add the file into main file
        time_main = pd.concat([time_main, time_file], ignore_index=True)
        
        #Read the stop file
        stop_file = pd.read_csv("gtfs/"+str(i)+"/google_transit/stops.txt")
        #filter stop file with the stop id extract from pervious step
        stop_file = stop_file[stop_file['stop_id'].isin(stop_id_list)]

        #Add the file into main file
        stop_main = pd.concat([stop_main, stop_file], ignore_index=True)
    print(i,'is done')
# Out:
# 2 is done
# 10 is done

# %%
print('stop_main:',len(stop_main))
print('time_main:',len(time_main))
# Out:
# stop_main: 287
# time_main: 22697

# %%
time_main.head()
# Out:
#                      trip_id arrival_time departure_time  stop_id  \
# 0  1051.T0.1-V08-G-mjp-1.1.H     06:08:00       06:08:00    20291
# 1  1051.T0.1-V08-G-mjp-1.1.H     06:42:00       06:42:00    20346
# 2  1051.T0.1-V08-G-mjp-1.1.H     06:55:00       06:57:00    20341
# 3  1051.T0.1-V08-G-mjp-1.1.H     07:16:00       07:16:00    20339
# 4  1051.T0.1-V08-G-mjp-1.1.H     07:32:00       07:34:00    20351
#
#    stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0              1            NaN            0              0
# 1              2            NaN            0              0
# 2              3            NaN            0              0
# 3              4            NaN            0              0
# 4              5            NaN            0              0
#
#    shape_dist_traveled
# 0             0.000000
# 1         52720.840026
# 2         68786.649688
# 3         94514.728171
# 4        116895.210301

# %%
#delate the column is not using
del time_main['stop_headsign']
del time_main['pickup_type']
del time_main['drop_off_type']
del time_main['shape_dist_traveled']
time_main.head()
# Out:
#                      trip_id arrival_time departure_time  stop_id  \
# 0  1051.T0.1-V08-G-mjp-1.1.H     06:08:00       06:08:00    20291
# 1  1051.T0.1-V08-G-mjp-1.1.H     06:42:00       06:42:00    20346
# 2  1051.T0.1-V08-G-mjp-1.1.H     06:55:00       06:57:00    20341
# 3  1051.T0.1-V08-G-mjp-1.1.H     07:16:00       07:16:00    20339
# 4  1051.T0.1-V08-G-mjp-1.1.H     07:32:00       07:34:00    20351
#
#    stop_sequence
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
#found the closed station id, distance in meter
def found_station(lat,long):
    station = ""
    smallest_distance = 10000
    route = 0
    result = []
    try:
        #check each station data in stop_main
        for i in range(len(stop_main)):
            #calculate the distance between the house and station base on latitude and lontitude, the distance in meter
            cal_distance = geodesic((stop_main.loc[i,'stop_lat'],stop_main.loc[i,'stop_lon']), (lat,long)).m
            #if the calculated distance is smaller than the current smallest_distance
            if cal_distance < smallest_distance:
                #record the stop_id
                station = stop_main.loc[i,'stop_id']
                #record the distance
                smallest_distance = cal_distance

        #result is a list, the first item of list is stop_id, the second item of list is distance.
        result = [station,smallest_distance]
        return result
    except Exception as ex:
        result = [0, 0]
    finally:
        return result

# %%
station_list = []
distance_list = []

# determine the closest station and distance of each house
for i in range(len(house)):
    station_distance_route = []
    station_distance_route = found_station(house.loc[i,'Lattitude'],house.loc[i,'Longtitude'])
    station_list.append(station_distance_route[0])
    distance_list.append(station_distance_route[1])
    print('number of row need processing:',len(house)-i-1)

house['train_station_id'] = station_list
house['distance_to_train_station'] = distance_list
# Out:
# number of row need processing: 677
# number of row need processing: 676
# number of row need processing: 675
# number of row need processing: 674
# number of row need processing: 673
# number of row need processing: 672
# number of row need processing: 671
# number of row need processing: 670
# number of row need processing: 669
# number of row need processing: 668
# number of row need processing: 667
# number of row need processing: 666
# number of row need processing: 665
# number of row need processing: 664
# number of row need processing: 663
# number of row need processing: 662
# number of row need processing: 661
# number of row need processing: 660
# number of row need processing: 659
# number of row need processing: 658
# number of row need processing: 657
# number of row need processing: 656
# number of row need processing: 655
# number of row need processing: 654
# number of row need processing: 653
# number of row need processing: 652
# number of row need processing: 651
# number of row need processing: 650
# number of row need processing: 649
# number of row need processing: 648
# number of row need processing: 647
# number of row need processing: 646
# number of row need processing: 645
# number of row need processing: 644
# number of row need processing: 643
# number of row need processing: 642
# number of row need processing: 641
# number of row need processing: 640
# number of row need processing: 639
# number of row need processing: 638
# number of row need processing: 637
# number of row need processing: 636
# number of row need processing: 635
# number of row need processing: 634
# number of row need processing: 633
# number of row need processing: 632
# number of row need processing: 631
# number of row need processing: 630
# number of row need processing: 629
# number of row need processing: 628
# number of row need processing: 627
# number of row need processing: 626
# number of row need processing: 625
# number of row need processing: 624
# number of row need processing: 623
# number of row need processing: 622
# number of row need processing: 621
# number of row need processing: 620
# number of row need processing: 619
# number of row need processing: 618
# number of row need processing: 617
# number of row need processing: 616
# number of row need processing: 615
# number of row need processing: 614
# number of row need processing: 613
# number of row need processing: 612
# number of row need processing: 611
# number of row need processing: 610
# number of row need processing: 609
# number of row need processing: 608
# number of row need processing: 607
# number of row need processing: 606
# number of row need processing: 605
# number of row need processing: 604
# number of row need processing: 603
# number of row need processing: 602
# number of row need processing: 601
# number of row need processing: 600
# number of row need processing: 599
# number of row need processing: 598
# number of row need processing: 597
# number of row need processing: 596
# number of row need processing: 595
# number of row need processing: 594
# number of row need processing: 593
# number of row need processing: 592
# number of row need processing: 591
# number of row need processing: 590
# number of row need processing: 589
# number of row need processing: 588
# number of row need processing: 587
# number of row need processing: 586
# number of row need processing: 585
# number of row need processing: 584
# number of row need processing: 583
# number of row need processing: 582
# number of row need processing: 581
# number of row need processing: 580
# number of row need processing: 579
# number of row need processing: 578
# number of row need processing: 577
# number of row need processing: 576
# number of row need processing: 575
# number of row need processing: 574
# number of row need processing: 573
# number of row need processing: 572
# number of row need processing: 571
# number of row need processing: 570
# number of row need processing: 569
# number of row need processing: 568
# number of row need processing: 567
# number of row need processing: 566
# number of row need processing: 565
# number of row need processing: 564
# number of row need processing: 563
# number of row need processing: 562
# number of row need processing: 561
# number of row need processing: 560
# number of row need processing: 559
# number of row need processing: 558
# number of row need processing: 557
# number of row need processing: 556
# number of row need processing: 555
# number of row need processing: 554
# number of row need processing: 553
# number of row need processing: 552
# number of row need processing: 551
# number of row need processing: 550
# number of row need processing: 549
# number of row need processing: 548
# number of row need processing: 547
# number of row need processing: 546
# number of row need processing: 545
# number of row need processing: 544
# number of row need processing: 543
# number of row need processing: 542
# number of row need processing: 541
# number of row need processing: 540
# number of row need processing: 539
# number of row need processing: 538
# number of row need processing: 537
# number of row need processing: 536
# number of row need processing: 535
# number of row need processing: 534
# number of row need processing: 533
# number of row need processing: 532
# number of row need processing: 531
# number of row need processing: 530
# number of row need processing: 529
# number of row need processing: 528
# number of row need processing: 527
# number of row need processing: 526
# number of row need processing: 525
# number of row need processing: 524
# number of row need processing: 523
# number of row need processing: 522
# number of row need processing: 521
# number of row need processing: 520
# number of row need processing: 519
# number of row need processing: 518
# number of row need processing: 517
# number of row need processing: 516
# number of row need processing: 515
# number of row need processing: 514
# number of row need processing: 513
# number of row need processing: 512
# number of row need processing: 511
# number of row need processing: 510
# number of row need processing: 509
# number of row need processing: 508
# number of row need processing: 507
# number of row need processing: 506
# number of row need processing: 505
# number of row need processing: 504
# number of row need processing: 503
# number of row need processing: 502
# number of row need processing: 501
# number of row need processing: 500
# number of row need processing: 499
# number of row need processing: 498
# number of row need processing: 497
# number of row need processing: 496
# number of row need processing: 495
# number of row need processing: 494
# number of row need processing: 493
# number of row need processing: 492
# number of row need processing: 491
# number of row need processing: 490
# number of row need processing: 489
# number of row need processing: 488
# number of row need processing: 487
# number of row need processing: 486
# number of row need processing: 485
# number of row need processing: 484
# number of row need processing: 483
# number of row need processing: 482
# number of row need processing: 481
# number of row need processing: 480
# number of row need processing: 479
# number of row need processing: 478
# number of row need processing: 477
# number of row need processing: 476
# number of row need processing: 475
# number of row need processing: 474
# number of row need processing: 473
# number of row need processing: 472
# number of row need processing: 471
# number of row need processing: 470
# number of row need processing: 469
# number of row need processing: 468
# number of row need processing: 467
# number of row need processing: 466
# number of row need processing: 465
# number of row need processing: 464
# number of row need processing: 463
# number of row need processing: 462
# number of row need processing: 461
# number of row need processing: 460
# number of row need processing: 459
# number of row need processing: 458
# number of row need processing: 457
# number of row need processing: 456
# number of row need processing: 455
# number of row need processing: 454
# number of row need processing: 453
# number of row need processing: 452
# number of row need processing: 451
# number of row need processing: 450
# number of row need processing: 449
# number of row need processing: 448
# number of row need processing: 447
# number of row need processing: 446
# number of row need processing: 445
# number of row need processing: 444
# number of row need processing: 443
# number of row need processing: 442
# number of row need processing: 441
# number of row need processing: 440
# number of row need processing: 439
# number of row need processing: 438
# number of row need processing: 437
# number of row need processing: 436
# number of row need processing: 435
# number of row need processing: 434
# number of row need processing: 433
# number of row need processing: 432
# number of row need processing: 431
# number of row need processing: 430
# number of row need processing: 429
# number of row need processing: 428
# number of row need processing: 427
# number of row need processing: 426
# number of row need processing: 425
# number of row need processing: 424
# number of row need processing: 423
# number of row need processing: 422
# number of row need processing: 421
# number of row need processing: 420
# number of row need processing: 419
# number of row need processing: 418
# number of row need processing: 417
# number of row need processing: 416
# number of row need processing: 415
# number of row need processing: 414
# number of row need processing: 413
# number of row need processing: 412
# number of row need processing: 411
# number of row need processing: 410
# number of row need processing: 409
# number of row need processing: 408
# number of row need processing: 407
# number of row need processing: 406
# number of row need processing: 405
# number of row need processing: 404
# number of row need processing: 403
# number of row need processing: 402
# number of row need processing: 401
# number of row need processing: 400
# number of row need processing: 399
# number of row need processing: 398
# number of row need processing: 397
# number of row need processing: 396
# number of row need processing: 395
# number of row need processing: 394
# number of row need processing: 393
# number of row need processing: 392
# number of row need processing: 391
# number of row need processing: 390
# number of row need processing: 389
# number of row need processing: 388
# number of row need processing: 387
# number of row need processing: 386
# number of row need processing: 385
# number of row need processing: 384
# number of row need processing: 383
# number of row need processing: 382
# number of row need processing: 381
# number of row need processing: 380
# number of row need processing: 379
# number of row need processing: 378
# number of row need processing: 377
# number of row need processing: 376
# number of row need processing: 375
# number of row need processing: 374
# number of row need processing: 373
# number of row need processing: 372
# number of row need processing: 371
# number of row need processing: 370
# number of row need processing: 369
# number of row need processing: 368
# number of row need processing: 367
# number of row need processing: 366
# number of row need processing: 365
# number of row need processing: 364
# number of row need processing: 363
# number of row need processing: 362
# number of row need processing: 361
# number of row need processing: 360
# number of row need processing: 359
# number of row need processing: 358
# number of row need processing: 357
# number of row need processing: 356
# number of row need processing: 355
# number of row need processing: 354
# number of row need processing: 353
# number of row need processing: 352
# number of row need processing: 351
# number of row need processing: 350
# number of row need processing: 349
# number of row need processing: 348
# number of row need processing: 347
# number of row need processing: 346
# number of row need processing: 345
# number of row need processing: 344
# number of row need processing: 343
# number of row need processing: 342
# number of row need processing: 341
# number of row need processing: 340
# number of row need processing: 339
# number of row need processing: 338
# number of row need processing: 337
# number of row need processing: 336
# number of row need processing: 335
# number of row need processing: 334
# number of row need processing: 333
# number of row need processing: 332
# number of row need processing: 331
# number of row need processing: 330
# number of row need processing: 329
# number of row need processing: 328
# number of row need processing: 327
# number of row need processing: 326
# number of row need processing: 325
# number of row need processing: 324
# number of row need processing: 323
# number of row need processing: 322
# number of row need processing: 321
# number of row need processing: 320
# number of row need processing: 319
# number of row need processing: 318
# number of row need processing: 317
# number of row need processing: 316
# number of row need processing: 315
# number of row need processing: 314
# number of row need processing: 313
# number of row need processing: 312
# number of row need processing: 311
# number of row need processing: 310
# number of row need processing: 309
# number of row need processing: 308
# number of row need processing: 307
# number of row need processing: 306
# number of row need processing: 305
# number of row need processing: 304
# number of row need processing: 303
# number of row need processing: 302
# number of row need processing: 301
# number of row need processing: 300
# number of row need processing: 299
# number of row need processing: 298
# number of row need processing: 297
# number of row need processing: 296
# number of row need processing: 295
# number of row need processing: 294
# number of row need processing: 293
# number of row need processing: 292
# number of row need processing: 291
# number of row need processing: 290
# number of row need processing: 289
# number of row need processing: 288
# number of row need processing: 287
# number of row need processing: 286
# number of row need processing: 285
# number of row need processing: 284
# number of row need processing: 283
# number of row need processing: 282
# number of row need processing: 281
# number of row need processing: 280
# number of row need processing: 279
# number of row need processing: 278
# number of row need processing: 277
# number of row need processing: 276
# number of row need processing: 275
# number of row need processing: 274
# number of row need processing: 273
# number of row need processing: 272
# number of row need processing: 271
# number of row need processing: 270
# number of row need processing: 269
# number of row need processing: 268
# number of row need processing: 267
# number of row need processing: 266
# number of row need processing: 265
# number of row need processing: 264
# number of row need processing: 263
# number of row need processing: 262
# number of row need processing: 261
# number of row need processing: 260
# number of row need processing: 259
# number of row need processing: 258
# number of row need processing: 257
# number of row need processing: 256
# number of row need processing: 255
# number of row need processing: 254
# number of row need processing: 253
# number of row need processing: 252
# number of row need processing: 251
# number of row need processing: 250
# number of row need processing: 249
# number of row need processing: 248
# number of row need processing: 247
# number of row need processing: 246
# number of row need processing: 245
# number of row need processing: 244
# number of row need processing: 243
# number of row need processing: 242
# number of row need processing: 241
# number of row need processing: 240
# number of row need processing: 239
# number of row need processing: 238
# number of row need processing: 237
# number of row need processing: 236
# number of row need processing: 235
# number of row need processing: 234
# number of row need processing: 233
# number of row need processing: 232
# number of row need processing: 231
# number of row need processing: 230
# number of row need processing: 229
# number of row need processing: 228
# number of row need processing: 227
# number of row need processing: 226
# number of row need processing: 225
# number of row need processing: 224
# number of row need processing: 223
# number of row need processing: 222
# number of row need processing: 221
# number of row need processing: 220
# number of row need processing: 219
# number of row need processing: 218
# number of row need processing: 217
# number of row need processing: 216
# number of row need processing: 215
# number of row need processing: 214
# number of row need processing: 213
# number of row need processing: 212
# number of row need processing: 211
# number of row need processing: 210
# number of row need processing: 209
# number of row need processing: 208
# number of row need processing: 207
# number of row need processing: 206
# number of row need processing: 205
# number of row need processing: 204
# number of row need processing: 203
# number of row need processing: 202
# number of row need processing: 201
# number of row need processing: 200
# number of row need processing: 199
# number of row need processing: 198
# number of row need processing: 197
# number of row need processing: 196
# number of row need processing: 195
# number of row need processing: 194
# number of row need processing: 193
# number of row need processing: 192
# number of row need processing: 191
# number of row need processing: 190
# number of row need processing: 189
# number of row need processing: 188
# number of row need processing: 187
# number of row need processing: 186
# number of row need processing: 185
# number of row need processing: 184
# number of row need processing: 183
# number of row need processing: 182
# number of row need processing: 181
# number of row need processing: 180
# number of row need processing: 179
# number of row need processing: 178
# number of row need processing: 177
# number of row need processing: 176
# number of row need processing: 175
# number of row need processing: 174
# number of row need processing: 173
# number of row need processing: 172
# number of row need processing: 171
# number of row need processing: 170
# number of row need processing: 169
# number of row need processing: 168
# number of row need processing: 167
# number of row need processing: 166
# number of row need processing: 165
# number of row need processing: 164
# number of row need processing: 163
# number of row need processing: 162
# number of row need processing: 161
# number of row need processing: 160
# number of row need processing: 159
# number of row need processing: 158
# number of row need processing: 157
# number of row need processing: 156
# number of row need processing: 155
# number of row need processing: 154
# number of row need processing: 153
# number of row need processing: 152
# number of row need processing: 151
# number of row need processing: 150
# number of row need processing: 149
# number of row need processing: 148
# number of row need processing: 147
# number of row need processing: 146
# number of row need processing: 145
# number of row need processing: 144
# number of row need processing: 143
# number of row need processing: 142
# number of row need processing: 141
# number of row need processing: 140
# number of row need processing: 139
# number of row need processing: 138
# number of row need processing: 137
# number of row need processing: 136
# number of row need processing: 135
# number of row need processing: 134
# number of row need processing: 133
# number of row need processing: 132
# number of row need processing: 131
# number of row need processing: 130
# number of row need processing: 129
# number of row need processing: 128
# number of row need processing: 127
# number of row need processing: 126
# number of row need processing: 125
# number of row need processing: 124
# number of row need processing: 123
# number of row need processing: 122
# number of row need processing: 121
# number of row need processing: 120
# number of row need processing: 119
# number of row need processing: 118
# number of row need processing: 117
# number of row need processing: 116
# number of row need processing: 115
# number of row need processing: 114
# number of row need processing: 113
# number of row need processing: 112
# number of row need processing: 111
# number of row need processing: 110
# number of row need processing: 109
# number of row need processing: 108
# number of row need processing: 107
# number of row need processing: 106
# number of row need processing: 105
# number of row need processing: 104
# number of row need processing: 103
# number of row need processing: 102
# number of row need processing: 101
# number of row need processing: 100
# number of row need processing: 99
# number of row need processing: 98
# number of row need processing: 97
# number of row need processing: 96
# number of row need processing: 95
# number of row need processing: 94
# number of row need processing: 93
# number of row need processing: 92
# number of row need processing: 91
# number of row need processing: 90
# number of row need processing: 89
# number of row need processing: 88
# number of row need processing: 87
# number of row need processing: 86
# number of row need processing: 85
# number of row need processing: 84
# number of row need processing: 83
# number of row need processing: 82
# number of row need processing: 81
# number of row need processing: 80
# number of row need processing: 79
# number of row need processing: 78
# number of row need processing: 77
# number of row need processing: 76
# number of row need processing: 75
# number of row need processing: 74
# number of row need processing: 73
# number of row need processing: 72
# number of row need processing: 71
# number of row need processing: 70
# number of row need processing: 69
# number of row need processing: 68
# number of row need processing: 67
# number of row need processing: 66
# number of row need processing: 65
# number of row need processing: 64
# number of row need processing: 63
# number of row need processing: 62
# number of row need processing: 61
# number of row need processing: 60
# number of row need processing: 59
# number of row need processing: 58
# number of row need processing: 57
# number of row need processing: 56
# number of row need processing: 55
# number of row need processing: 54
# number of row need processing: 53
# number of row need processing: 52
# number of row need processing: 51
# number of row need processing: 50
# number of row need processing: 49
# number of row need processing: 48
# number of row need processing: 47
# number of row need processing: 46
# number of row need processing: 45
# number of row need processing: 44
# number of row need processing: 43
# number of row need processing: 42
# number of row need processing: 41
# number of row need processing: 40
# number of row need processing: 39
# number of row need processing: 38
# number of row need processing: 37
# number of row need processing: 36
# number of row need processing: 35
# number of row need processing: 34
# number of row need processing: 33
# number of row need processing: 32
# number of row need processing: 31
# number of row need processing: 30
# number of row need processing: 29
# number of row need processing: 28
# number of row need processing: 27
# number of row need processing: 26
# number of row need processing: 25
# number of row need processing: 24
# number of row need processing: 23
# number of row need processing: 22
# number of row need processing: 21
# number of row need processing: 20
# number of row need processing: 19
# number of row need processing: 18
# number of row need processing: 17
# number of row need processing: 16
# number of row need processing: 15
# number of row need processing: 14
# number of row need processing: 13
# number of row need processing: 12
# number of row need processing: 11
# number of row need processing: 10
# number of row need processing: 9
# number of row need processing: 8
# number of row need processing: 7
# number of row need processing: 6
# number of row need processing: 5
# number of row need processing: 4
# number of row need processing: 3
# number of row need processing: 2
# number of row need processing: 1
# number of row need processing: 0

# %%
house['distance_to_train_station'].describe()
# Out:
# count     678.000000
# mean     1400.738216
# std      1131.164634
# min        42.110197
# 25%       590.593895
# 50%      1028.299659
# 75%      1836.712534
# max      8267.454609
# Name: distance_to_train_station, dtype: float64

# %%
house.head()
# Out:
#             ID             Address  Rooms Type      Price        Date  \
# 0  ID524428873     14 Woodmason St      3    h  1437000.0  16/04/2016
# 1  ID455142191       85 Radford Rd      5    h   791000.0  18/06/2016
# 2  ID385314378       34 Fewster Dr      3    h   970000.0  26/08/2017
# 3  ID205782381      41 Adelaide St      3    h   760000.0  23/09/2017
# 4  ID574190434  1/221 Westgarth St      3    t   865000.0  12/11/2016
#
#    Bathroom  Car  Landsize    Age  Lattitude  Longtitude          Suburb  \
# 0       1.0  1.0     313.0  109.0  -37.85110   145.03170         MALVERN
# 1       3.0  1.0     961.0   34.0  -37.70240   144.98400       RESERVOIR
# 2       2.0  2.0     674.0   38.0  -37.88360   145.22805  WANTIRNA SOUTH
# 3       1.0  1.0     697.0   69.0  -37.78036   144.81950          ALBION
# 4       1.0  2.0     184.0   13.0  -37.78250   145.01040       NORTHCOTE
#
#    over_priced?  crime_A_average  crime_B_average  crime_C_average  \
# 0             0              610             1743              228
# 1             0              824             1890              159
# 2             0               98              190               19
# 3             1              298              735              154
# 4             0              136              302               42
#
#    train_station_id  distance_to_train_station
# 0             19945                1240.535013
# 1             19961                2223.991693
# 2             19869                5582.978901
# 3             20004                 548.114894
# 4             19929                 413.938549

# %% [markdown]
# ### 1.5 calculate the time

# %%
# Find the list of row index with stop_id departure bewteen 07:00 and 09:30
def find_station_time(stop_id):
    result = time_main[(time_main['stop_id']==stop_id)&(time_main['departure_time']> '06:59:59')&(time_main['departure_time']< '09:30:01')]
    return list(result.index.values)

# %%
#base on the index found, calculate time 
def find_time(index,SC_list):
    try:
        # found the trip id base on input index
        temp_trip_id = time_main.loc[index,'trip_id']
        #found the index of southern cross station in the same trip
        sc_index = list(time_main[(time_main['trip_id']==temp_trip_id)&(time_main['stop_id'].isin(SC_list))].index.values)[0]
        #if the southern cross station is before the stop_id, then return 0
        if (time_main.loc[sc_index, 'stop_sequence']<time_main.loc[index, 'stop_sequence']) or (sc_index<index):
            result = 0
        else:
            #calculate the time by calculate the difference of arrival time of southern cross station and departure time of stop station
            # in minutes
            calculate_time =  pd.to_datetime(time_main.loc[sc_index, 'arrival_time'])- pd.to_datetime(time_main.loc[index, 'departure_time'])
            result = calculate_time.seconds/60
    except Exception as ex:
        result = 0
    finally:
        return result

# %%
# determine the mean of value in the list
def calculate_mean(calculate_list):
    result = 0
    for i in calculate_list:
        result+=i
    return result/len(calculate_list)

# %%
# calculate the final mean time
def calculate_time(stop_id,SC_id):
    list_found =[]
    calculate_result = []
    try:
        # Find the row index list with stop_id departure bewteen 07:00 and 09:30, make index into list
        list_found = find_station_time(stop_id)
        #cacluation time of each index
        for i in list_found:
            calculate_time = find_time(i,SC_id)
            # if the time is 0 or more than 1440 minutes which is 1 day, the result will not add to final result
            if (calculate_time != 0)&(calculate_time<1440):
                calculate_result.append(calculate_time)
        #calculating the mean of time
        result = calculate_mean(calculate_result)
    except Exception as ex:
        result = 0
    finally:
        return result

# %%
#calcuate the travel_min_to CBD for each row
calculate_time_result = []
for i in range(len(house)):
    temp_result = 0
    temp_result = calculate_time(house.loc[i,'train_station_id'],SC_id)
    calculate_time_result.append(temp_result)
    print('result:',temp_result)
    print('number of row need processing:',len(house)-i-1)

house['travel_min_to_CBD'] = calculate_time_result
# Out:
# result: 19.214285714285715
# number of row need processing: 677
# result: 39.0
# number of row need processing: 676
# result: 48.18181818181818
# number of row need processing: 675
# result: 26.375
# number of row need processing: 674
# result: 19.923076923076923
# number of row need processing: 673
# result: 38.0
# number of row need processing: 672
# result: 27.333333333333332
# number of row need processing: 671
# result: 34.666666666666664
# number of row need processing: 670
# result: 26.0
# number of row need processing: 669
# result: 49.22222222222222
# number of row need processing: 668
# result: 23.3
# number of row need processing: 667
# result: 30.666666666666668
# number of row need processing: 666
# result: 36.41379310344828
# number of row need processing: 665
# result: 22.0
# number of row need processing: 664
# result: 21.785714285714285
# number of row need processing: 663
# result: 13.235294117647058
# number of row need processing: 662
# result: 0
# number of row need processing: 661
# result: 18.214285714285715
# number of row need processing: 660
# result: 18.333333333333332
# number of row need processing: 659
# result: 13.235294117647058
# number of row need processing: 658
# result: 17.4
# number of row need processing: 657
# result: 26.058823529411764
# number of row need processing: 656
# result: 12.235294117647058
# number of row need processing: 655
# result: 29.0
# number of row need processing: 654
# result: 3.4078212290502794
# number of row need processing: 653
# result: 37.666666666666664
# number of row need processing: 652
# result: 31.666666666666668
# number of row need processing: 651
# result: 19.5
# number of row need processing: 650
# result: 16.214285714285715
# number of row need processing: 649
# result: 33.5
# number of row need processing: 648
# result: 29.35483870967742
# number of row need processing: 647
# result: 32.0
# number of row need processing: 646
# result: 29.35483870967742
# number of row need processing: 645
# result: 29.0
# number of row need processing: 644
# result: 49.0
# number of row need processing: 643
# result: 31.5
# number of row need processing: 642
# result: 33.5
# number of row need processing: 641
# result: 31.5
# number of row need processing: 640
# result: 18.333333333333332
# number of row need processing: 639
# result: 19.09090909090909
# number of row need processing: 638
# result: 40.22222222222222
# number of row need processing: 637
# result: 18.333333333333332
# number of row need processing: 636
# result: 27.0
# number of row need processing: 635
# result: 21.4
# number of row need processing: 634
# result: 10.0
# number of row need processing: 633
# result: 26.058823529411764
# number of row need processing: 632
# result: 35.2
# number of row need processing: 631
# result: 18.333333333333332
# number of row need processing: 630
# result: 18.333333333333332
# number of row need processing: 629
# result: 20.857142857142858
# number of row need processing: 628
# result: 20.0
# number of row need processing: 627
# result: 25.333333333333332
# number of row need processing: 626
# result: 27.0
# number of row need processing: 625
# result: 13.5
# number of row need processing: 624
# result: 18.333333333333332
# number of row need processing: 623
# result: 22.0
# number of row need processing: 622
# result: 34.75
# number of row need processing: 621
# result: 34.75
# number of row need processing: 620
# result: 32.0
# number of row need processing: 619
# result: 39.48148148148148
# number of row need processing: 618
# result: 31.2
# number of row need processing: 617
# result: 15.142857142857142
# number of row need processing: 616
# result: 19.923076923076923
# number of row need processing: 615
# result: 24.428571428571427
# number of row need processing: 614
# result: 25.333333333333332
# number of row need processing: 613
# result: 19.4
# number of row need processing: 612
# result: 26.428571428571427
# number of row need processing: 611
# result: 13.5
# number of row need processing: 610
# result: 34.375
# number of row need processing: 609
# result: 23.5
# number of row need processing: 608
# result: 36.84615384615385
# number of row need processing: 607
# result: 19.4
# number of row need processing: 606
# result: 17.4
# number of row need processing: 605
# result: 39.48148148148148
# number of row need processing: 604
# result: 25.3
# number of row need processing: 603
# result: 32.0
# number of row need processing: 602
# result: 36.41379310344828
# number of row need processing: 601
# result: 31.75
# number of row need processing: 600
# result: 19.09090909090909
# number of row need processing: 599
# result: 22.75
# number of row need processing: 598
# result: 21.4
# number of row need processing: 597
# result: 15.85
# number of row need processing: 596
# result: 12.235294117647058
# number of row need processing: 595
# result: 29.23076923076923
# number of row need processing: 594
# result: 31.75
# number of row need processing: 593
# result: 25.375
# number of row need processing: 592
# result: 17.0
# number of row need processing: 591
# result: 13.952380952380953
# number of row need processing: 590
# result: 18.333333333333332
# number of row need processing: 589
# result: 41.642857142857146
# number of row need processing: 588
# result: 31.35483870967742
# number of row need processing: 587
# result: 12.235294117647058
# number of row need processing: 586
# result: 19.214285714285715
# number of row need processing: 585
# result: 54.15384615384615
# number of row need processing: 584
# result: 32.0
# number of row need processing: 583
# result: 34.0
# number of row need processing: 582
# result: 40.166666666666664
# number of row need processing: 581
# result: 16.310344827586206
# number of row need processing: 580
# result: 24.333333333333332
# number of row need processing: 579
# result: 13.5
# number of row need processing: 578
# result: 30.666666666666668
# number of row need processing: 577
# result: 6.100558659217877
# number of row need processing: 576
# result: 0
# number of row need processing: 575
# result: 33.5
# number of row need processing: 574
# result: 16.214285714285715
# number of row need processing: 573
# result: 3.5
# number of row need processing: 572
# result: 12.543859649122806
# number of row need processing: 571
# result: 19.923076923076923
# number of row need processing: 570
# result: 28.666666666666668
# number of row need processing: 569
# result: 36.84615384615385
# number of row need processing: 568
# result: 18.333333333333332
# number of row need processing: 567
# result: 18.333333333333332
# number of row need processing: 566
# result: 17.5
# number of row need processing: 565
# result: 25.775
# number of row need processing: 564
# result: 18.333333333333332
# number of row need processing: 563
# result: 52.0
# number of row need processing: 562
# result: 31.375
# number of row need processing: 561
# result: 35.2
# number of row need processing: 560
# result: 29.375
# number of row need processing: 559
# result: 26.3
# number of row need processing: 558
# result: 15.5
# number of row need processing: 557
# result: 22.0
# number of row need processing: 556
# result: 37.666666666666664
# number of row need processing: 555
# result: 23.5
# number of row need processing: 554
# result: 31.2
# number of row need processing: 553
# result: 28.5
# number of row need processing: 552
# result: 31.0
# number of row need processing: 551
# result: 27.0
# number of row need processing: 550
# result: 26.666666666666668
# number of row need processing: 549
# result: 19.4
# number of row need processing: 548
# result: 4.7444444444444445
# number of row need processing: 547
# result: 20.857142857142858
# number of row need processing: 546
# result: 25.775
# number of row need processing: 545
# result: 37.666666666666664
# number of row need processing: 544
# result: 9.125
# number of row need processing: 543
# result: 18.333333333333332
# number of row need processing: 542
# result: 13.5
# number of row need processing: 541
# result: 31.0
# number of row need processing: 540
# result: 18.333333333333332
# number of row need processing: 539
# result: 10.357142857142858
# number of row need processing: 538
# result: 19.214285714285715
# number of row need processing: 537
# result: 32.0
# number of row need processing: 536
# result: 19.4
# number of row need processing: 535
# result: 12.235294117647058
# number of row need processing: 534
# result: 31.75
# number of row need processing: 533
# result: 24.5
# number of row need processing: 532
# result: 34.75
# number of row need processing: 531
# result: 25.333333333333332
# number of row need processing: 530
# result: 36.0
# number of row need processing: 529
# result: 15.666666666666666
# number of row need processing: 528
# result: 25.5
# number of row need processing: 527
# result: 36.0
# number of row need processing: 526
# result: 32.15384615384615
# number of row need processing: 525
# result: 27.333333333333332
# number of row need processing: 524
# result: 26.5
# number of row need processing: 523
# result: 11.904761904761905
# number of row need processing: 522
# result: 20.857142857142858
# number of row need processing: 521
# result: 12.235294117647058
# number of row need processing: 520
# result: 68.81818181818181
# number of row need processing: 519
# result: 17.904761904761905
# number of row need processing: 518
# result: 29.823529411764707
# number of row need processing: 517
# result: 38.266666666666666
# number of row need processing: 516
# result: 47.9
# number of row need processing: 515
# result: 21.4
# number of row need processing: 514
# result: 34.0
# number of row need processing: 513
# result: 42.22222222222222
# number of row need processing: 512
# result: 19.4
# number of row need processing: 511
# result: 47.06666666666667
# number of row need processing: 510
# result: 18.333333333333332
# number of row need processing: 509
# result: 28.785714285714285
# number of row need processing: 508
# result: 24.428571428571427
# number of row need processing: 507
# result: 36.0
# number of row need processing: 506
# result: 34.375
# number of row need processing: 505
# result: 35.15384615384615
# number of row need processing: 504
# result: 19.4
# number of row need processing: 503
# result: 12.543859649122806
# number of row need processing: 502
# result: 17.904761904761905
# number of row need processing: 501
# result: 26.0
# number of row need processing: 500
# result: 31.5
# number of row need processing: 499
# result: 25.3
# number of row need processing: 498
# result: 12.235294117647058
# number of row need processing: 497
# result: 19.0
# number of row need processing: 496
# result: 26.5
# number of row need processing: 495
# result: 37.666666666666664
# number of row need processing: 494
# result: 21.4
# number of row need processing: 493
# result: 30.5
# number of row need processing: 492
# result: 25.333333333333332
# number of row need processing: 491
# result: 21.4
# number of row need processing: 490
# result: 24.333333333333332
# number of row need processing: 489
# result: 28.5
# number of row need processing: 488
# result: 29.375
# number of row need processing: 487
# result: 25.76923076923077
# number of row need processing: 486
# result: 24.333333333333332
# number of row need processing: 485
# result: 10.235294117647058
# number of row need processing: 484
# result: 27.35483870967742
# number of row need processing: 483
# result: 68.81818181818181
# number of row need processing: 482
# result: 21.5
# number of row need processing: 481
# result: 40.22222222222222
# number of row need processing: 480
# result: 35.15384615384615
# number of row need processing: 479
# result: 27.333333333333332
# number of row need processing: 478
# result: 26.0
# number of row need processing: 477
# result: 24.0
# number of row need processing: 476
# result: 16.310344827586206
# number of row need processing: 475
# result: 27.0
# number of row need processing: 474
# result: 30.818181818181817
# number of row need processing: 473
# result: 25.333333333333332
# number of row need processing: 472
# result: 26.0
# number of row need processing: 471
# result: 19.4
# number of row need processing: 470
# result: 25.76923076923077
# number of row need processing: 469
# result: 48.166666666666664
# number of row need processing: 468
# result: 28.785714285714285
# number of row need processing: 467
# result: 31.2
# number of row need processing: 466
# result: 38.266666666666666
# number of row need processing: 465
# result: 27.0
# number of row need processing: 464
# result: 16.214285714285715
# number of row need processing: 463
# result: 16.310344827586206
# number of row need processing: 462
# result: 23.5
# number of row need processing: 461
# result: 15.142857142857142
# number of row need processing: 460
# result: 11.904761904761905
# number of row need processing: 459
# result: 37.666666666666664
# number of row need processing: 458
# result: 17.5
# number of row need processing: 457
# result: 31.2
# number of row need processing: 456
# result: 18.214285714285715
# number of row need processing: 455
# result: 28.666666666666668
# number of row need processing: 454
# result: 36.84615384615385
# number of row need processing: 453
# result: 11.357142857142858
# number of row need processing: 452
# result: 27.0
# number of row need processing: 451
# result: 31.35483870967742
# number of row need processing: 450
# result: 39.0
# number of row need processing: 449
# result: 29.0
# number of row need processing: 448
# result: 23.76923076923077
# number of row need processing: 447
# result: 32.0
# number of row need processing: 446
# result: 19.5
# number of row need processing: 445
# result: 34.0
# number of row need processing: 444
# result: 37.0
# number of row need processing: 443
# result: 25.5
# number of row need processing: 442
# result: 46.0
# number of row need processing: 441
# result: 31.35483870967742
# number of row need processing: 440
# result: 47.9
# number of row need processing: 439
# result: 32.15384615384615
# number of row need processing: 438
# result: 31.35483870967742
# number of row need processing: 437
# result: 13.5
# number of row need processing: 436
# result: 12.543859649122806
# number of row need processing: 435
# result: 33.5
# number of row need processing: 434
# result: 39.0
# number of row need processing: 433
# result: 39.0
# number of row need processing: 432
# result: 17.5
# number of row need processing: 431
# result: 38.266666666666666
# number of row need processing: 430
# result: 21.333333333333332
# number of row need processing: 429
# result: 11.357142857142858
# number of row need processing: 428
# result: 28.785714285714285
# number of row need processing: 427
# result: 15.666666666666666
# number of row need processing: 426
# result: 68.81818181818181
# number of row need processing: 425
# result: 21.5
# number of row need processing: 424
# result: 30.0
# number of row need processing: 423
# result: 26.3
# number of row need processing: 422
# result: 25.333333333333332
# number of row need processing: 421
# result: 18.333333333333332
# number of row need processing: 420
# result: 15.666666666666666
# number of row need processing: 419
# result: 15.666666666666666
# number of row need processing: 418
# result: 29.0
# number of row need processing: 417
# result: 28.666666666666668
# number of row need processing: 416
# result: 26.0
# number of row need processing: 415
# result: 38.0
# number of row need processing: 414
# result: 25.375
# number of row need processing: 413
# result: 38.41379310344828
# number of row need processing: 412
# result: 14.333333333333334
# number of row need processing: 411
# result: 27.35483870967742
# number of row need processing: 410
# result: 25.775
# number of row need processing: 409
# result: 21.4
# number of row need processing: 408
# result: 32.0
# number of row need processing: 407
# result: 25.775
# number of row need processing: 406
# result: 29.0
# number of row need processing: 405
# result: 0
# number of row need processing: 404
# result: 21.5
# number of row need processing: 403
# result: 37.0
# number of row need processing: 402
# result: 29.0
# number of row need processing: 401
# result: 32.15384615384615
# number of row need processing: 400
# result: 20.0
# number of row need processing: 399
# result: 12.543859649122806
# number of row need processing: 398
# result: 21.5
# number of row need processing: 397
# result: 28.785714285714285
# number of row need processing: 396
# result: 26.058823529411764
# number of row need processing: 395
# result: 25.5
# number of row need processing: 394
# result: 16.310344827586206
# number of row need processing: 393
# result: 13.5
# number of row need processing: 392
# result: 28.666666666666668
# number of row need processing: 391
# result: 15.85
# number of row need processing: 390
# result: 45.083333333333336
# number of row need processing: 389
# result: 26.5
# number of row need processing: 388
# result: 31.5
# number of row need processing: 387
# result: 18.333333333333332
# number of row need processing: 386
# result: 15.666666666666666
# number of row need processing: 385
# result: 15.666666666666666
# number of row need processing: 384
# result: 35.142857142857146
# number of row need processing: 383
# result: 25.5
# number of row need processing: 382
# result: 28.666666666666668
# number of row need processing: 381
# result: 19.3
# number of row need processing: 380
# result: 0
# number of row need processing: 379
# result: 18.333333333333332
# number of row need processing: 378
# result: 31.2
# number of row need processing: 377
# result: 40.166666666666664
# number of row need processing: 376
# result: 20.0
# number of row need processing: 375
# result: 0
# number of row need processing: 374
# result: 19.5
# number of row need processing: 373
# result: 37.0
# number of row need processing: 372
# result: 11.357142857142858
# number of row need processing: 371
# result: 10.18918918918919
# number of row need processing: 370
# result: 21.4
# number of row need processing: 369
# result: 30.307692307692307
# number of row need processing: 368
# result: 0
# number of row need processing: 367
# result: 16.214285714285715
# number of row need processing: 366
# result: 36.84615384615385
# number of row need processing: 365
# result: 21.4
# number of row need processing: 364
# result: 19.5
# number of row need processing: 363
# result: 22.0
# number of row need processing: 362
# result: 47.9
# number of row need processing: 361
# result: 7.0
# number of row need processing: 360
# result: 16.214285714285715
# number of row need processing: 359
# result: 26.666666666666668
# number of row need processing: 358
# result: 16.214285714285715
# number of row need processing: 357
# result: 10.235294117647058
# number of row need processing: 356
# result: 36.0
# number of row need processing: 355
# result: 20.0
# number of row need processing: 354
# result: 24.5
# number of row need processing: 353
# result: 19.5
# number of row need processing: 352
# result: 38.266666666666666
# number of row need processing: 351
# result: 36.84615384615385
# number of row need processing: 350
# result: 19.4
# number of row need processing: 349
# result: 35.15384615384615
# number of row need processing: 348
# result: 19.214285714285715
# number of row need processing: 347
# result: 37.666666666666664
# number of row need processing: 346
# result: 34.2
# number of row need processing: 345
# result: 20.0
# number of row need processing: 344
# result: 30.666666666666668
# number of row need processing: 343
# result: 26.5
# number of row need processing: 342
# result: 21.4
# number of row need processing: 341
# result: 34.2
# number of row need processing: 340
# result: 20.8
# number of row need processing: 339
# result: 22.333333333333332
# number of row need processing: 338
# result: 19.214285714285715
# number of row need processing: 337
# result: 12.235294117647058
# number of row need processing: 336
# result: 35.15384615384615
# number of row need processing: 335
# result: 31.75
# number of row need processing: 334
# result: 14.333333333333334
# number of row need processing: 333
# result: 25.76923076923077
# number of row need processing: 332
# result: 31.75
# number of row need processing: 331
# result: 20.0
# number of row need processing: 330
# result: 62.0
# number of row need processing: 329
# result: 45.76923076923077
# number of row need processing: 328
# result: 19.09090909090909
# number of row need processing: 327
# result: 39.6
# number of row need processing: 326
# result: 38.0
# number of row need processing: 325
# result: 29.823529411764707
# number of row need processing: 324
# result: 25.775
# number of row need processing: 323
# result: 10.357142857142858
# number of row need processing: 322
# result: 32.15384615384615
# number of row need processing: 321
# result: 37.666666666666664
# number of row need processing: 320
# result: 49.22222222222222
# number of row need processing: 319
# result: 35.15384615384615
# number of row need processing: 318
# result: 15.142857142857142
# number of row need processing: 317
# result: 18.214285714285715
# number of row need processing: 316
# result: 21.3
# number of row need processing: 315
# result: 50.06666666666667
# number of row need processing: 314
# result: 15.5
# number of row need processing: 313
# result: 27.333333333333332
# number of row need processing: 312
# result: 0
# number of row need processing: 311
# result: 23.3
# number of row need processing: 310
# result: 27.333333333333332
# number of row need processing: 309
# result: 17.904761904761905
# number of row need processing: 308
# result: 21.5
# number of row need processing: 307
# result: 25.333333333333332
# number of row need processing: 306
# result: 28.785714285714285
# number of row need processing: 305
# result: 31.5
# number of row need processing: 304
# result: 34.0
# number of row need processing: 303
# result: 39.0
# number of row need processing: 302
# result: 19.214285714285715
# number of row need processing: 301
# result: 41.083333333333336
# number of row need processing: 300
# result: 43.9
# number of row need processing: 299
# result: 42.166666666666664
# number of row need processing: 298
# result: 0
# number of row need processing: 297
# result: 31.75
# number of row need processing: 296
# result: 34.2
# number of row need processing: 295
# result: 28.3
# number of row need processing: 294
# result: 38.22222222222222
# number of row need processing: 293
# result: 12.543859649122806
# number of row need processing: 292
# result: 4.7444444444444445
# number of row need processing: 291
# result: 30.0
# number of row need processing: 290
# result: 33.15384615384615
# number of row need processing: 289
# result: 47.06666666666667
# number of row need processing: 288
# result: 21.333333333333332
# number of row need processing: 287
# result: 45.0
# number of row need processing: 286
# result: 22.0
# number of row need processing: 285
# result: 20.8
# number of row need processing: 284
# result: 30.666666666666668
# number of row need processing: 283
# result: 3.5
# number of row need processing: 282
# result: 68.81818181818181
# number of row need processing: 281
# result: 44.34615384615385
# number of row need processing: 280
# result: 30.307692307692307
# number of row need processing: 279
# result: 28.5
# number of row need processing: 278
# result: 17.5
# number of row need processing: 277
# result: 38.266666666666666
# number of row need processing: 276
# result: 10.235294117647058
# number of row need processing: 275
# result: 18.333333333333332
# number of row need processing: 274
# result: 38.266666666666666
# number of row need processing: 273
# result: 34.0
# number of row need processing: 272
# result: 0
# number of row need processing: 271
# result: 43.9
# number of row need processing: 270
# result: 18.214285714285715
# number of row need processing: 269
# result: 43.9
# number of row need processing: 268
# result: 29.823529411764707
# number of row need processing: 267
# result: 38.0
# number of row need processing: 266
# result: 15.666666666666666
# number of row need processing: 265
# result: 23.76923076923077
# number of row need processing: 264
# result: 19.5
# number of row need processing: 263
# result: 38.266666666666666
# number of row need processing: 262
# result: 20.857142857142858
# number of row need processing: 261
# result: 24.333333333333332
# number of row need processing: 260
# result: 34.0
# number of row need processing: 259
# result: 22.333333333333332
# number of row need processing: 258
# result: 28.785714285714285
# number of row need processing: 257
# result: 23.5
# number of row need processing: 256
# result: 32.15384615384615
# number of row need processing: 255
# result: 16.310344827586206
# number of row need processing: 254
# result: 66.81818181818181
# number of row need processing: 253
# result: 17.4
# number of row need processing: 252
# result: 12.543859649122806
# number of row need processing: 251
# result: 28.785714285714285
# number of row need processing: 250
# result: 21.785714285714285
# number of row need processing: 249
# result: 39.6
# number of row need processing: 248
# result: 32.15384615384615
# number of row need processing: 247
# result: 39.6
# number of row need processing: 246
# result: 20.0
# number of row need processing: 245
# result: 20.8
# number of row need processing: 244
# result: 36.0
# number of row need processing: 243
# result: 49.0
# number of row need processing: 242
# result: 18.333333333333332
# number of row need processing: 241
# result: 33.666666666666664
# number of row need processing: 240
# result: 18.333333333333332
# number of row need processing: 239
# result: 22.0
# number of row need processing: 238
# result: 3.5
# number of row need processing: 237
# result: 23.76923076923077
# number of row need processing: 236
# result: 19.5
# number of row need processing: 235
# result: 19.5
# number of row need processing: 234
# result: 43.9
# number of row need processing: 233
# result: 39.48148148148148
# number of row need processing: 232
# result: 46.0
# number of row need processing: 231
# result: 41.666666666666664
# number of row need processing: 230
# result: 16.214285714285715
# number of row need processing: 229
# result: 54.15384615384615
# number of row need processing: 228
# result: 31.0
# number of row need processing: 227
# result: 21.4
# number of row need processing: 226
# result: 27.333333333333332
# number of row need processing: 225
# result: 13.5
# number of row need processing: 224
# result: 16.310344827586206
# number of row need processing: 223
# result: 11.357142857142858
# number of row need processing: 222
# result: 26.058823529411764
# number of row need processing: 221
# result: 33.666666666666664
# number of row need processing: 220
# result: 32.15384615384615
# number of row need processing: 219
# result: 19.5
# number of row need processing: 218
# result: 21.5
# number of row need processing: 217
# result: 21.4
# number of row need processing: 216
# result: 13.952380952380953
# number of row need processing: 215
# result: 29.823529411764707
# number of row need processing: 214
# result: 6.100558659217877
# number of row need processing: 213
# result: 23.76923076923077
# number of row need processing: 212
# result: 35.15384615384615
# number of row need processing: 211
# result: 19.5
# number of row need processing: 210
# result: 38.0
# number of row need processing: 209
# result: 26.666666666666668
# number of row need processing: 208
# result: 15.85
# number of row need processing: 207
# result: 24.5
# number of row need processing: 206
# result: 32.0
# number of row need processing: 205
# result: 29.0
# number of row need processing: 204
# result: 30.0
# number of row need processing: 203
# result: 35.142857142857146
# number of row need processing: 202
# result: 34.2
# number of row need processing: 201
# result: 17.4
# number of row need processing: 200
# result: 21.4
# number of row need processing: 199
# result: 25.775
# number of row need processing: 198
# result: 7.0
# number of row need processing: 197
# result: 11.904761904761905
# number of row need processing: 196
# result: 18.214285714285715
# number of row need processing: 195
# result: 33.666666666666664
# number of row need processing: 194
# result: 6.100558659217877
# number of row need processing: 193
# result: 15.142857142857142
# number of row need processing: 192
# result: 16.214285714285715
# number of row need processing: 191
# result: 31.0
# number of row need processing: 190
# result: 21.5
# number of row need processing: 189
# result: 26.5
# number of row need processing: 188
# result: 32.09090909090909
# number of row need processing: 187
# result: 40.166666666666664
# number of row need processing: 186
# result: 23.5
# number of row need processing: 185
# result: 38.266666666666666
# number of row need processing: 184
# result: 9.125
# number of row need processing: 183
# result: 16.310344827586206
# number of row need processing: 182
# result: 12.543859649122806
# number of row need processing: 181
# result: 20.857142857142858
# number of row need processing: 180
# result: 16.310344827586206
# number of row need processing: 179
# result: 13.5
# number of row need processing: 178
# result: 13.5
# number of row need processing: 177
# result: 17.5
# number of row need processing: 176
# result: 45.22222222222222
# number of row need processing: 175
# result: 41.46153846153846
# number of row need processing: 174
# result: 26.3
# number of row need processing: 173
# result: 10.18918918918919
# number of row need processing: 172
# result: 31.2
# number of row need processing: 171
# result: 34.75
# number of row need processing: 170
# result: 35.15384615384615
# number of row need processing: 169
# result: 36.0
# number of row need processing: 168
# result: 10.0
# number of row need processing: 167
# result: 31.666666666666668
# number of row need processing: 166
# result: 26.0
# number of row need processing: 165
# result: 38.266666666666666
# number of row need processing: 164
# result: 17.4
# number of row need processing: 163
# result: 34.0
# number of row need processing: 162
# result: 0
# number of row need processing: 161
# result: 61.3
# number of row need processing: 160
# result: 25.775
# number of row need processing: 159
# result: 18.333333333333332
# number of row need processing: 158
# result: 30.307692307692307
# number of row need processing: 157
# result: 33.15384615384615
# number of row need processing: 156
# result: 25.3
# number of row need processing: 155
# result: 45.22222222222222
# number of row need processing: 154
# result: 24.0
# number of row need processing: 153
# result: 19.4
# number of row need processing: 152
# result: 18.333333333333332
# number of row need processing: 151
# result: 18.333333333333332
# number of row need processing: 150
# result: 11.904761904761905
# number of row need processing: 149
# result: 30.818181818181817
# number of row need processing: 148
# result: 18.0
# number of row need processing: 147
# result: 25.5
# number of row need processing: 146
# result: 34.0
# number of row need processing: 145
# result: 34.2
# number of row need processing: 144
# result: 19.3
# number of row need processing: 143
# result: 3.4078212290502794
# number of row need processing: 142
# result: 16.214285714285715
# number of row need processing: 141
# result: 6.4
# number of row need processing: 140
# result: 20.8
# number of row need processing: 139
# result: 18.333333333333332
# number of row need processing: 138
# result: 18.333333333333332
# number of row need processing: 137
# result: 30.307692307692307
# number of row need processing: 136
# result: 33.666666666666664
# number of row need processing: 135
# result: 34.666666666666664
# number of row need processing: 134
# result: 36.41379310344828
# number of row need processing: 133
# result: 29.823529411764707
# number of row need processing: 132
# result: 26.375
# number of row need processing: 131
# result: 20.8
# number of row need processing: 130
# result: 19.5
# number of row need processing: 129
# result: 18.333333333333332
# number of row need processing: 128
# result: 19.3
# number of row need processing: 127
# result: 18.3
# number of row need processing: 126
# result: 31.0
# number of row need processing: 125
# result: 38.0
# number of row need processing: 124
# result: 16.310344827586206
# number of row need processing: 123
# result: 0
# number of row need processing: 122
# result: 66.81818181818181
# number of row need processing: 121
# result: 39.6
# number of row need processing: 120
# result: 31.75
# number of row need processing: 119
# result: 31.35483870967742
# number of row need processing: 118
# result: 30.5
# number of row need processing: 117
# result: 17.0
# number of row need processing: 116
# result: 0
# number of row need processing: 115
# result: 45.22222222222222
# number of row need processing: 114
# result: 11.357142857142858
# number of row need processing: 113
# result: 30.5
# number of row need processing: 112
# result: 16.214285714285715
# number of row need processing: 111
# result: 34.666666666666664
# number of row need processing: 110
# result: 27.333333333333332
# number of row need processing: 109
# result: 31.666666666666668
# number of row need processing: 108
# result: 27.0
# number of row need processing: 107
# result: 10.235294117647058
# number of row need processing: 106
# result: 30.5
# number of row need processing: 105
# result: 6.100558659217877
# number of row need processing: 104
# result: 19.214285714285715
# number of row need processing: 103
# result: 34.2
# number of row need processing: 102
# result: 16.214285714285715
# number of row need processing: 101
# result: 28.785714285714285
# number of row need processing: 100
# result: 19.3
# number of row need processing: 99
# result: 18.0
# number of row need processing: 98
# result: 11.357142857142858
# number of row need processing: 97
# result: 10.18918918918919
# number of row need processing: 96
# result: 37.0
# number of row need processing: 95
# result: 29.35483870967742
# number of row need processing: 94
# result: 25.375
# number of row need processing: 93
# result: 20.857142857142858
# number of row need processing: 92
# result: 18.333333333333332
# number of row need processing: 91
# result: 11.904761904761905
# number of row need processing: 90
# result: 36.0
# number of row need processing: 89
# result: 15.666666666666666
# number of row need processing: 88
# result: 27.35483870967742
# number of row need processing: 87
# result: 22.333333333333332
# number of row need processing: 86
# result: 21.4
# number of row need processing: 85
# result: 17.904761904761905
# number of row need processing: 84
# result: 48.166666666666664
# number of row need processing: 83
# result: 13.5
# number of row need processing: 82
# result: 30.307692307692307
# number of row need processing: 81
# result: 24.428571428571427
# number of row need processing: 80
# result: 34.75
# number of row need processing: 79
# result: 28.785714285714285
# number of row need processing: 78
# result: 18.923076923076923
# number of row need processing: 77
# result: 35.0
# number of row need processing: 76
# result: 19.214285714285715
# number of row need processing: 75
# result: 26.375
# number of row need processing: 74
# result: 18.333333333333332
# number of row need processing: 73
# result: 51.333333333333336
# number of row need processing: 72
# result: 44.6875
# number of row need processing: 71
# result: 11.904761904761905
# number of row need processing: 70
# result: 30.307692307692307
# number of row need processing: 69
# result: 32.0
# number of row need processing: 68
# result: 30.5
# number of row need processing: 67
# result: 13.952380952380953
# number of row need processing: 66
# result: 29.823529411764707
# number of row need processing: 65
# result: 25.3
# number of row need processing: 64
# result: 3.5
# number of row need processing: 63
# result: 30.666666666666668
# number of row need processing: 62
# result: 22.0
# number of row need processing: 61
# result: 32.0
# number of row need processing: 60
# result: 31.666666666666668
# number of row need processing: 59
# result: 17.904761904761905
# number of row need processing: 58
# result: 47.06666666666667
# number of row need processing: 57
# result: 36.84615384615385
# number of row need processing: 56
# result: 12.543859649122806
# number of row need processing: 55
# result: 25.375
# number of row need processing: 54
# result: 24.5
# number of row need processing: 53
# result: 0
# number of row need processing: 52
# result: 26.058823529411764
# number of row need processing: 51
# result: 23.76923076923077
# number of row need processing: 50
# result: 32.0
# number of row need processing: 49
# result: 16.310344827586206
# number of row need processing: 48
# result: 19.5
# number of row need processing: 47
# result: 17.0
# number of row need processing: 46
# result: 45.75
# number of row need processing: 45
# result: 13.235294117647058
# number of row need processing: 44
# result: 25.333333333333332
# number of row need processing: 43
# result: 21.4
# number of row need processing: 42
# result: 26.3
# number of row need processing: 41
# result: 50.06666666666667
# number of row need processing: 40
# result: 30.666666666666668
# number of row need processing: 39
# result: 22.0
# number of row need processing: 38
# result: 18.923076923076923
# number of row need processing: 37
# result: 13.235294117647058
# number of row need processing: 36
# result: 19.3
# number of row need processing: 35
# result: 28.5
# number of row need processing: 34
# result: 24.333333333333332
# number of row need processing: 33
# result: 13.952380952380953
# number of row need processing: 32
# result: 18.333333333333332
# number of row need processing: 31
# result: 31.75
# number of row need processing: 30
# result: 29.23076923076923
# number of row need processing: 29
# result: 41.666666666666664
# number of row need processing: 28
# result: 34.0
# number of row need processing: 27
# result: 11.357142857142858
# number of row need processing: 26
# result: 21.4
# number of row need processing: 25
# result: 33.15384615384615
# number of row need processing: 24
# result: 23.3
# number of row need processing: 23
# result: 18.333333333333332
# number of row need processing: 22
# result: 28.5
# number of row need processing: 21
# result: 19.5
# number of row need processing: 20
# result: 34.0
# number of row need processing: 19
# result: 34.666666666666664
# number of row need processing: 18
# result: 22.0
# number of row need processing: 17
# result: 31.75
# number of row need processing: 16
# result: 26.3
# number of row need processing: 15
# result: 13.5
# number of row need processing: 14
# result: 15.142857142857142
# number of row need processing: 13
# result: 17.0
# number of row need processing: 12
# result: 29.0
# number of row need processing: 11
# result: 12.543859649122806
# number of row need processing: 10
# result: 29.35483870967742
# number of row need processing: 9
# result: 40.166666666666664
# number of row need processing: 8
# result: 18.333333333333332
# number of row need processing: 7
# result: 25.775
# number of row need processing: 6
# result: 30.666666666666668
# number of row need processing: 5
# result: 31.35483870967742
# number of row need processing: 4
# result: 15.666666666666666
# number of row need processing: 3
# result: 37.0
# number of row need processing: 2
# result: 31.2
# number of row need processing: 1
# result: 31.666666666666668
# number of row need processing: 0

# %%
# Check there is default value in travel minutes or not
house[house['travel_min_to_CBD']==0]
# Out:
#               ID            Address  Rooms Type      Price        Date  \
# 16   ID227991548     33 Mountain St      2    h  1150000.0   7/05/2016
# 102  ID416600038      137 Ingles St      3    t   950000.0  27/11/2016
# 273  ID659298165  139 Cruikshank St      3    t  1565000.0  16/04/2016
# 298  ID843381080     203 Station St      3    h  2400000.0   8/04/2017
# 303  ID501053980    364 Montague St      2    h  1562500.0  15/10/2016
# 310  ID830189796         67 Ross St      3    h  1665000.0   1/07/2017
# 366  ID727751584        40 Smith St      2    h   970000.0   9/09/2017
# 380  ID752913405  92/99 Whiteman St      2    u   650000.0   6/08/2016
# 406  ID442918930        10 Coote St      3    t  1185000.0  23/04/2016
# 516  ID479052371        21 Greig St      3    h  2500000.0   3/06/2017
# 555  ID128640315   13/52 Moubray St      1    u   442500.0  25/02/2017
# 562  ID396792128   85 Richardson St      2    h  1455000.0   3/09/2016
# 625  ID858879650    120/1 Graham St      3    u  1725000.0   3/06/2017
#
#      Bathroom  Car  Landsize    Age  Lattitude  Longtitude           Suburb  \
# 16        1.0  0.0     113.0  163.0  -37.83730   144.94930  SOUTH MELBOURNE
# 102       2.0  2.0       0.0    7.0  -37.83170   144.94460   PORT MELBOURNE
# 273       1.0  2.0     188.0  129.0  -37.83710   144.94780   PORT MELBOURNE
# 298       2.0  2.0     368.0  139.0  -37.83230   144.94630   PORT MELBOURNE
# 303       1.0  0.0     141.0  129.0  -37.84240   144.95620      ALBERT PARK
# 310       3.0  2.0     121.0    8.0  -37.83591   144.93648   PORT MELBOURNE
# 366       1.0  0.0      82.0  119.0  -37.83606   144.95164  SOUTH MELBOURNE
# 380       2.0  1.0       0.0   19.0  -37.82730   144.95560        SOUTHBANK
# 406       2.0  1.0     111.0   15.0  -37.83410   144.95410  SOUTH MELBOURNE
# 516       2.0  1.0     165.0  129.0  -37.84152   144.95027      ALBERT PARK
# 555       1.0  0.0       0.0   49.0  -37.84210   144.95170      ALBERT PARK
# 562       1.0  0.0     159.0  119.0  -37.84500   144.95380      ALBERT PARK
# 625       2.0  2.0       0.0   19.0  -37.84290   144.94487   PORT MELBOURNE
#
#      over_priced?  crime_A_average  crime_B_average  crime_C_average  \
# 16              0             1100             3636              457
# 102             0              659             5219              338
# 273             0              659             5219              338
# 298             0              705             5479              335
# 303             1             1202             5034              333
# 310             0              705             5479              335
# 366             0             1245             3886              447
# 380             1             1100             3636              457
# 406             0             1100             3636              457
# 516             0             1214             5603              375
# 555             0             1214             5603              375
# 562             0             1202             5034              333
# 625             0              705             5479              335
#
#      train_station_id  distance_to_train_station  travel_min_to_CBD
# 16              20043                2124.124142                0.0
# 102             20043                1639.384105                0.0
# 273             20043                2123.996226                0.0
# 298             20043                1644.126647                0.0
# 303             20043                2690.654439                0.0
# 310             22180                2389.094211                0.0
# 366             20043                1968.974984                0.0
# 380             20043                1031.305302                0.0
# 406             20043                1755.372455                0.0
# 516             20043                2581.102107                0.0
# 555             20043                2638.832974                0.0
# 562             20043                2961.842795                0.0
# 625             20043                2808.670401                0.0

# %%
# The row with 0 value, their station id is southern cross station, so the 0 value is reasonable,and then check the statistic information. 
house['travel_min_to_CBD'].describe()
# Out:
# count    678.000000
# mean      25.845148
# std       11.189522
# min        0.000000
# 25%       18.333333
# 50%       25.769231
# 75%       32.068182
# max       68.818182
# Name: travel_min_to_CBD, dtype: float64

# %% [markdown]
# ### 1.6 Reordering the columns, Final check and output the file

# %%
#Reordering the columns
column_order = ['ID','Address','Suburb','Price','Type','Date','Rooms','Bathroom', 'Car', 'Landsize','Age','Lattitude','Longtitude',
                'train_station_id','distance_to_train_station','travel_min_to_CBD', 'over_priced?', 'crime_A_average', 'crime_B_average',
               'crime_C_average']
house = house[column_order]
house.head()
# Out:
#             ID             Address          Suburb      Price Type  \
# 0  ID524428873     14 Woodmason St         MALVERN  1437000.0    h
# 1  ID455142191       85 Radford Rd       RESERVOIR   791000.0    h
# 2  ID385314378       34 Fewster Dr  WANTIRNA SOUTH   970000.0    h
# 3  ID205782381      41 Adelaide St          ALBION   760000.0    h
# 4  ID574190434  1/221 Westgarth St       NORTHCOTE   865000.0    t
#
#          Date  Rooms  Bathroom  Car  Landsize    Age  Lattitude  Longtitude  \
# 0  16/04/2016      3       1.0  1.0     313.0  109.0  -37.85110   145.03170
# 1  18/06/2016      5       3.0  1.0     961.0   34.0  -37.70240   144.98400
# 2  26/08/2017      3       2.0  2.0     674.0   38.0  -37.88360   145.22805
# 3  23/09/2017      3       1.0  1.0     697.0   69.0  -37.78036   144.81950
# 4  12/11/2016      3       1.0  2.0     184.0   13.0  -37.78250   145.01040
#
#    train_station_id  distance_to_train_station  travel_min_to_CBD  \
# 0             19945                1240.535013          19.214286
# 1             19961                2223.991693          39.000000
# 2             19869                5582.978901          48.181818
# 3             20004                 548.114894          26.375000
# 4             19929                 413.938549          19.923077
#
#    over_priced?  crime_A_average  crime_B_average  crime_C_average
# 0             0              610             1743              228
# 1             0              824             1890              159
# 2             0               98              190               19
# 3             1              298              735              154
# 4             0              136              302               42

# %%
house.to_csv('29910226_solution.csv',index=False)

# %% [markdown]
# ### 1.7 The error inside of data
# - The first error is the duplicated data inside data, so remove the duplicated data.
# - There is not enough data for over priced column, a lot of data have only itself in the group. As result, the over priced column for those data is false or 0, it did not mean it is not over priced.
# - For the travel time, it is depand on the closed station which have direct trip to southern cross in 7:00 am to 9:30 am. but there is some house may close to a station, but that station need transfer to other route to southern cross. In here, the true closest station did not have considered.

# %% [markdown]
# ## Task 2: Data Reshaping

# %% [markdown]
# - Try to orginal data as control group to compare firstly
# - Test 5 different method
# - Using the r-square value of linear regression model and plot to determine the effect of reshaping method.
# - The higher r-square value, it means better in linear regression model
# - The plots is the predictor against target, the plot should have a linear relation shape which the point should clustering in a straight line

# %%
#Since the 0 value in travel_min_to_CBD will cause problem in domain error in log and sprt root, so omit the data have 0 in travel time.
house = house[house['travel_min_to_CBD']!=0]
house= house.reset_index()
del house['index']
house.head()
# Out:
#             ID             Address          Suburb      Price Type  \
# 0  ID524428873     14 Woodmason St         MALVERN  1437000.0    h
# 1  ID455142191       85 Radford Rd       RESERVOIR   791000.0    h
# 2  ID385314378       34 Fewster Dr  WANTIRNA SOUTH   970000.0    h
# 3  ID205782381      41 Adelaide St          ALBION   760000.0    h
# 4  ID574190434  1/221 Westgarth St       NORTHCOTE   865000.0    t
#
#          Date  Rooms  Bathroom  Car  Landsize    Age  Lattitude  Longtitude  \
# 0  16/04/2016      3       1.0  1.0     313.0  109.0  -37.85110   145.03170
# 1  18/06/2016      5       3.0  1.0     961.0   34.0  -37.70240   144.98400
# 2  26/08/2017      3       2.0  2.0     674.0   38.0  -37.88360   145.22805
# 3  23/09/2017      3       1.0  1.0     697.0   69.0  -37.78036   144.81950
# 4  12/11/2016      3       1.0  2.0     184.0   13.0  -37.78250   145.01040
#
#    train_station_id  distance_to_train_station  travel_min_to_CBD  \
# 0             19945                1240.535013          19.214286
# 1             19961                2223.991693          39.000000
# 2             19869                5582.978901          48.181818
# 3             20004                 548.114894          26.375000
# 4             19929                 413.938549          19.923077
#
#    over_priced?  crime_A_average  crime_B_average  crime_C_average
# 0             0              610             1743              228
# 1             0              824             1890              159
# 2             0               98              190               19
# 3             1              298              735              154
# 4             0              136              302               42

# %%
# check the remaining lens of data
len(house)
# Out:
# 665

# %%
# Since the linear regression only using Rooms ,crime_C_average, travel_min_to_CBD , and property_age to predict Price
# drop the unused column in this task
del house['Address']
del house['Type']
del house['Date']
del house['Bathroom']
del house['Car']
del house['Landsize']
del house['Lattitude']
del house['Longtitude']
del house['Suburb']
del house['over_priced?']
del house['crime_A_average']
del house['crime_B_average']
del house['train_station_id']
del house['distance_to_train_station']
house.head()
# Out:
#             ID      Price  Rooms    Age  travel_min_to_CBD  crime_C_average
# 0  ID524428873  1437000.0      3  109.0          19.214286              228
# 1  ID455142191   791000.0      5   34.0          39.000000              159
# 2  ID385314378   970000.0      3   38.0          48.181818               19
# 3  ID205782381   760000.0      3   69.0          26.375000              154
# 4  ID574190434   865000.0      3   13.0          19.923077               42

# %%
# plot 4 figure of distribution, the x axis is the one of predictor attributes, the y axis is the target which is price, the left up plot 
# is room against price, the left down plot is crime against price, the right up plot is age against price, and the right down plot is 
# travel min against price
plt.figure(12)

plt.subplot(221)
plt.plot(house['Rooms'], house['Price'], 'ro')
plt.xlabel("Rooms")
plt.ylabel("Price")

plt.subplot(222)
plt.plot(house['Age'], house['Price'], 'ro')
plt.xlabel("Age")
plt.ylabel("Price")

plt.subplot(223)
plt.plot(house['crime_C_average'], house['Price'], 'ro')
plt.xlabel("crime")
plt.ylabel("Price")
    
plt.subplot(224)
plt.plot(house['travel_min_to_CBD'], house['Price'], 'ro')
plt.xlabel("travel")
plt.ylabel("Price")

plt.show()

# %%
#Test the orginal data in linear regression, to determine the r-square value, make orginal model as control group.
x_train, x_test, y_train, y_test = train_test_split(house.loc[:,("Rooms", "Age", "crime_C_average", "travel_min_to_CBD")], house['Price'], random_state = 1)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train) 
print("R-Spuare for orginal value model is", linear_model.score(x_test, y_test))
# Out:
# R-Spuare for orginal value model is 0.4237824442242575

# %% [markdown]
# ### 2.1 Standardisation

# %%
#Adding the 4 standardiszation value comlumns
house_std = house.copy()
std_scale = preprocessing.StandardScaler().fit(house_std[['Rooms', 'Age','crime_C_average','travel_min_to_CBD']])
df_std =std_scale.transform(house_std[['Rooms', 'Age','crime_C_average','travel_min_to_CBD']])
house_std['scaled_rooms'] = df_std[:,0] 
house_std['scaled_age'] = df_std[:,1] 
house_std['scaled_crime'] = df_std[:,2] 
house_std['scaled_travel'] = df_std[:,3] 
house_std.head()
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\David\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.
#             ID      Price  Rooms    Age  travel_min_to_CBD  crime_C_average  \
# 0  ID524428873  1437000.0      3  109.0          19.214286              228
# 1  ID455142191   791000.0      5   34.0          39.000000              159
# 2  ID385314378   970000.0      3   38.0          48.181818               19
# 3  ID205782381   760000.0      3   69.0          26.375000              154
# 4  ID574190434   865000.0      3   13.0          19.923077               42
#
#    scaled_rooms  scaled_age  scaled_crime  scaled_travel
# 0      0.043790    1.157747     -0.528164      -0.667914
# 1      2.123805   -0.471008     -0.710287       1.183958
# 2      0.043790   -0.384141     -1.079813       2.043344
# 3      0.043790    0.289078     -0.723484       0.002303
# 4      0.043790   -0.927060     -1.019105      -0.601574

# %%
# plot 4 figure of distribution, the x axis is the one of predictor attributes, the y axis is the target which is price, the left up plot 
# is room against price, the left down plot is crime against price, the right up plot is age against price, and the right down plot is 
# travel min against price
plt.figure(12)

plt.subplot(221)
plt.plot(house_std['scaled_rooms'], house_std['Price'], 'ro')
plt.xlabel("Rooms")
plt.ylabel("Price")

plt.subplot(222)
plt.plot(house_std['scaled_age'], house_std['Price'], 'ro')
plt.xlabel("Age")
plt.ylabel("Price")

plt.subplot(223)
plt.plot(house_std['scaled_crime'], house_std['Price'], 'ro')
plt.xlabel("crime")
plt.ylabel("Price")
    
plt.subplot(224)
plt.plot(house_std['scaled_travel'], house_std['Price'], 'ro')
plt.xlabel("travel")
plt.ylabel("Price")

plt.show()

# %%
#Test the scaled data in linear regression, to determine the r-square value
x_train, x_test, y_train, y_test = train_test_split(house_std.loc[:,("scaled_rooms", "scaled_age", "scaled_crime", "scaled_travel")], house_std['Price'], random_state = 1)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train) 
print("R-Spuare for Standardisation value model is", linear_model.score(x_test, y_test))
# Out:
# R-Spuare for Standardisation value model is 0.4237824442242576

# %% [markdown]
# ### 2.2 min-max normalization

# %%
#Adding the 4 min-max normalization value comlumns
house_minmax = house.copy()
minmax_scale = preprocessing.MinMaxScaler().fit(house_minmax[['Rooms', 'Age','crime_C_average','travel_min_to_CBD']])
df_minmax =minmax_scale.transform(house_minmax[['Rooms', 'Age','crime_C_average','travel_min_to_CBD']])
house_minmax['scaled_rooms'] = df_minmax[:,0] 
house_minmax['scaled_age'] = df_minmax[:,1] 
house_minmax['scaled_crime'] = df_minmax[:,2] 
house_minmax['scaled_travel'] = df_minmax[:,3] 
house_minmax.head()
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#             ID      Price  Rooms    Age  travel_min_to_CBD  crime_C_average  \
# 0  ID524428873  1437000.0      3  109.0          19.214286              228
# 1  ID455142191   791000.0      5   34.0          39.000000              159
# 2  ID385314378   970000.0      3   38.0          48.181818               19
# 3  ID205782381   760000.0      3   69.0          26.375000              154
# 4  ID574190434   865000.0      3   13.0          19.923077               42
#
#    scaled_rooms  scaled_age  scaled_crime  scaled_travel
# 0           0.4    0.130329      0.109475       0.241651
# 1           0.8    0.038977      0.075601       0.544137
# 2           0.4    0.043849      0.006873       0.684509
# 3           0.4    0.081608      0.073147       0.351124
# 4           0.4    0.013398      0.018164       0.252487

# %%
# plot 4 figure of distribution, the x axis is the one of predictor attributes, the y axis is the target which is price, the left up plot 
# is room against price, the left down plot is crime against price, the right up plot is age against price, and the right down plot is 
# travel min against price
plt.figure(12)

plt.subplot(221)
plt.plot(house_minmax['scaled_rooms'], house_minmax['Price'], 'ro')
plt.xlabel("Rooms")
plt.ylabel("Price")

plt.subplot(222)
plt.plot(house_minmax['scaled_age'], house_minmax['Price'], 'ro')
plt.xlabel("Age")
plt.ylabel("Price")

plt.subplot(223)
plt.plot(house_minmax['scaled_crime'], house_minmax['Price'], 'ro')
plt.xlabel("crime")
plt.ylabel("Price")
    
plt.subplot(224)
plt.plot(house_minmax['scaled_travel'], house_minmax['Price'], 'ro')
plt.xlabel("travel")
plt.ylabel("Price")

plt.show()

# %%
#Test the scaled data in linear regression, to determine the r-square value
x_train, x_test, y_train, y_test = train_test_split(house_minmax.loc[:,("scaled_rooms", "scaled_age", "scaled_crime", "scaled_travel")], house_minmax['Price'], random_state = 1)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train) 
print("R-Spuare for Min_max value model is", linear_model.score(x_test, y_test))
# Out:
# R-Spuare for Min_max value model is 0.42378244422425726

# %% [markdown]
# ### 2.3 log transformation

# %%
#Adding the log transformation value comlumns
house_log = house.copy()
house_log['scaled_rooms'] = None 
house_log['scaled_age'] = None  
house_log['scaled_crime'] = None  
house_log['scaled_travel'] = None 

for i in range(len(house_log)):
    house_log.loc[i,'scaled_rooms'] = math.log(house_log.loc[i,"Rooms"])
    house_log.loc[i,'scaled_age'] = math.log(house_log.loc[i,"Age"])
    house_log.loc[i,'scaled_crime'] = math.log(house_log.loc[i,"crime_C_average"])
    house_log.loc[i,'scaled_travel'] = math.log(house_log.loc[i,"travel_min_to_CBD"])

house_log.head()
# Out:
#             ID      Price  Rooms    Age  travel_min_to_CBD  crime_C_average  \
# 0  ID524428873  1437000.0      3  109.0          19.214286              228
# 1  ID455142191   791000.0      5   34.0          39.000000              159
# 2  ID385314378   970000.0      3   38.0          48.181818               19
# 3  ID205782381   760000.0      3   69.0          26.375000              154
# 4  ID574190434   865000.0      3   13.0          19.923077               42
#
#   scaled_rooms scaled_age scaled_crime scaled_travel
# 0      1.09861    4.69135      5.42935       2.95565
# 1      1.60944    3.52636       5.0689       3.66356
# 2      1.09861    3.63759      2.94444       3.87498
# 3      1.09861    4.23411      5.03695       3.27242
# 4      1.09861    2.56495      3.73767       2.99188

# %%
# plot 4 figure of distribution, the x axis is the one of predictor attributes, the y axis is the target which is price, the left up plot 
# is room against price, the left down plot is crime against price, the right up plot is age against price, and the right down plot is 
# travel min against price
plt.figure(12)
    
plt.subplot(221)
plt.plot(house_log['scaled_rooms'], house_log['Price'], 'ro')
plt.xlabel("Rooms")
plt.ylabel("Price")

plt.subplot(222)
plt.plot(house_log['scaled_age'], house_log['Price'], 'ro')
plt.xlabel("Age")
plt.ylabel("Price")

plt.subplot(223)
plt.plot(house_log['scaled_crime'], house_log['Price'], 'ro')
plt.xlabel("crime")
plt.ylabel("Price")
    
plt.subplot(224)
plt.plot(house_log['scaled_travel'], house_log['Price'], 'ro')
plt.xlabel("travel")
plt.ylabel("Price")

plt.show()

# %%
#Test the scaled data in linear regression, to determine the r-square value
x_train, x_test, y_train, y_test = train_test_split(house_log.loc[:,("scaled_rooms", "scaled_age", "scaled_crime", "scaled_travel")], house_log['Price'], random_state = 1)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train) 
print("R-Spuare for Log value model is", linear_model.score(x_test, y_test))
# Out:
# R-Spuare for Log value model is 0.3987061765730303

# %% [markdown]
# ### 2.4 power transformation

# %%
#Adding the power transformation value comlumns
house_power = house.copy()
house_power['scaled_rooms'] = None 
house_power['scaled_age'] = None  
house_power['scaled_crime'] = None  
house_power['scaled_travel'] = None 

for i in range(len(house_power)):
    house_power.loc[i,'scaled_rooms'] = math.pow(house_power.loc[i,"Rooms"],2)
    house_power.loc[i,'scaled_age'] = math.pow(house_power.loc[i,"Age"],2)
    house_power.loc[i,'scaled_crime'] = math.pow(house_power.loc[i,"crime_C_average"],2)
    house_power.loc[i,'scaled_travel'] = math.pow(house_power.loc[i,"travel_min_to_CBD"],2)

house_power.head()
# Out:
#             ID      Price  Rooms    Age  travel_min_to_CBD  crime_C_average  \
# 0  ID524428873  1437000.0      3  109.0          19.214286              228
# 1  ID455142191   791000.0      5   34.0          39.000000              159
# 2  ID385314378   970000.0      3   38.0          48.181818               19
# 3  ID205782381   760000.0      3   69.0          26.375000              154
# 4  ID574190434   865000.0      3   13.0          19.923077               42
#
#    scaled_rooms  scaled_age  scaled_crime scaled_travel
# 0             9       11881         51984       369.189
# 1            25        1156         25281          1521
# 2             9        1444           361       2321.49
# 3             9        4761         23716       695.641
# 4             9         169          1764       396.929

# %%
# plot 4 figure of distribution, the x axis is the one of predictor attributes, the y axis is the target which is price, the left up plot 
# is room against price, the left down plot is crime against price, the right up plot is age against price, and the right down plot is 
# travel min against price
plt.figure(12)
    
plt.subplot(221)
plt.plot(house_power['scaled_rooms'], house_power['Price'], 'ro')
plt.xlabel("Rooms")
plt.ylabel("Price")

plt.subplot(222)
plt.plot(house_power['scaled_age'], house_power['Price'], 'ro')
plt.xlabel("Age")
plt.ylabel("Price")

plt.subplot(223)
plt.plot(house_power['scaled_crime'], house_power['Price'], 'ro')
plt.xlabel("crime")
plt.ylabel("Price")
    
plt.subplot(224)
plt.plot(house_power['scaled_travel'], house_power['Price'], 'ro')
plt.xlabel("travel")
plt.ylabel("Price")

plt.show()

# %%
#Test the scaled data in linear regression, to determine the r-square value
x_train, x_test, y_train, y_test = train_test_split(house_power.loc[:,("scaled_rooms", "scaled_age", "scaled_crime", "scaled_travel")], house_power['Price'], random_state = 1)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train) 
print("R-Spuare for Power value model is", linear_model.score(x_test, y_test))
# Out:
# R-Spuare for Power value model is 0.3396477284456786

# %% [markdown]
# ### 2.5 root transformation

# %%
#Adding the root transformation value comlumns
house_root = house.copy()
house_root['scaled_rooms'] = None 
house_root['scaled_age'] = None  
house_root['scaled_crime'] = None  
house_root['scaled_travel'] = None 

for i in range(len(house_root)):
    house_root.loc[i,'scaled_rooms'] = math.sqrt(house_root.loc[i,"Rooms"])
    house_root.loc[i,'scaled_age'] = math.sqrt(house_root.loc[i,"Age"])
    house_root.loc[i,'scaled_crime'] = math.sqrt(house_root.loc[i,"crime_C_average"])
    house_root.loc[i,'scaled_travel'] = math.sqrt(house_root.loc[i,"travel_min_to_CBD"])

house_root.head()
# Out:
#             ID      Price  Rooms    Age  travel_min_to_CBD  crime_C_average  \
# 0  ID524428873  1437000.0      3  109.0          19.214286              228
# 1  ID455142191   791000.0      5   34.0          39.000000              159
# 2  ID385314378   970000.0      3   38.0          48.181818               19
# 3  ID205782381   760000.0      3   69.0          26.375000              154
# 4  ID574190434   865000.0      3   13.0          19.923077               42
#
#   scaled_rooms scaled_age scaled_crime scaled_travel
# 0      1.73205    10.4403      15.0997       4.38341
# 1      2.23607    5.83095      12.6095         6.245
# 2      1.73205    6.16441       4.3589       6.94131
# 3      1.73205    8.30662      12.4097       5.13566
# 4      1.73205    3.60555      6.48074       4.46353

# %%
# plot 4 figure of distribution, the x axis is the one of predictor attributes, the y axis is the target which is price, the left up plot 
# is room against price, the left down plot is crime against price, the right up plot is age against price, and the right down plot is 
# travel min against price
plt.figure(12)
    
plt.subplot(221)
plt.plot(house_root['scaled_rooms'], house_root['Price'], 'ro')
plt.xlabel("Rooms")
plt.ylabel("Price")

plt.subplot(222)
plt.plot(house_root['scaled_age'], house_root['Price'], 'ro')
plt.xlabel("Age")
plt.ylabel("Price")

plt.subplot(223)
plt.plot(house_root['scaled_crime'], house_root['Price'], 'ro')
plt.xlabel("crime")
plt.ylabel("Price")
    
plt.subplot(224)
plt.plot(house_root['scaled_travel'], house_root['Price'], 'ro')
plt.xlabel("travel")
plt.ylabel("Price")

plt.show()

# %%
#Test the scaled data in linear regression, to determine the r-square value
x_train, x_test, y_train, y_test = train_test_split(house_root.loc[:,("scaled_rooms", "scaled_age", "scaled_crime", "scaled_travel")], house_root['Price'], random_state = 1)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train) 
print("R-Spuare for Root value model is", linear_model.score(x_test, y_test))
# Out:
# R-Spuare for Root value model is 0.43812115593279555

# %% [markdown]
# ### 2.6 Conclusion

# %% [markdown]
# - The plots did not show any big difference, so the plots can not be used to determine the effect of reshaping method
# - Base on the R-square value for each model, the orginally model r-square value is 0.42. The standlization and min_max model have mostly same r-square with orginal model, so those two models did not impove the accurate of model. In power model, the r-square is even getting worse to  0.34, so the power model even make it worse. The log model did not improve in the r-sqaure, its r-sqaure value is 0.40 which is a little bit worse than original model. The root transformation model have best r-Square which is 0.438 which is slightly better than the original data. So the root transformation linear model best method in this data.
